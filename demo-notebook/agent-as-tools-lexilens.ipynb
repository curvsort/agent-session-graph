# %% [markdown]
# "Agents as Tools" is an architectural pattern in AI systems where specialized AI agents are wrapped as callable functions (tools) that can be used by other agents. This creates a hierarchical structure where:
#
# 1. A primary "orchestrator" agent handles user interaction and determines which specialized agent to call
#
# 2. Specialized "tool agents" perform domain-specific tasks when called by the orchestrator
#
# This approach mimics human team dynamics, where a manager coordinates specialists, each bringing unique expertise to solve complex problems. Rather than a single agent trying to handle everything, tasks are delegated to the most appropriate specialized agent.

# %% [markdown]
# ## Key Benefits and Core Principles

# %% [markdown]
# The "Agents as Tools" pattern offers several advantages:
#
# - Separation of concerns: Each agent has a focused area of responsibility, making the system easier to understand and maintain
# - Hierarchical delegation: The orchestrator decides which specialist to invoke, creating a clear chain of command
# - Modular architecture: Specialists can be added, removed, or modified independently without affecting the entire system
# - Improved performance: Each agent can have tailored system prompts and tools optimized for its specific task

# %%
import sys
print(sys.executable)
# Out:
# /Users/rbakshi/Downloads/agentic_ai/samples/python/01-learn/10-agents-as-tools/.venv/bin/python

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: strands-agents in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.41.0)
# Requirement already satisfied: strands-agents-tools in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.43.24)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.43.24)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.18.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.23.0)
# Requirement already satisfied: mcp<2.0.0,>=1.23.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.27.1)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.42.1)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.63b1)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.42.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.13.5)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: pillow<13.0.0,>=12.1.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (12.2.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.52)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.13.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.3.4)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.28.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.13.3)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.24.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.19.0,>=0.18.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (0.18.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.19.1)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.12.3)
# Requirement already satisfied: six<2,>=1.15 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: anyio>=4.5 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (4.13.0)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: httpx<1.0.0,>=0.27.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (2.14.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.0.29)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (3.4.4)
# Requirement already satisfied: starlette>=0.27 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.48.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.63b1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.63b1)
# Requirement already satisfied: wrapt<3.0.0,>=1.0.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.63b1->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.63b1)
# Requirement already satisfied: packaging>=18.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.63b1->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (24.1)
# Requirement already satisfied: wcwidth in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (2.46.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.18.0)
# Requirement already satisfied: slack_sdk<4,>=3.38.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.42.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.5)
# Requirement already satisfied: httpcore==1.* in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from httpx<1.0.0,>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: cryptography>=3.4.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (48.0.0)
# Requirement already satisfied: click>=7.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (8.4.1)
# Requirement already satisfied: cffi>=2.0.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pycparser in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (2.22)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import strands
import boto3
import pydantic

print("All imports successful")
# Out:
# All imports successful

# %%
import os

from strands import Agent, tool
from strands_tools import file_write

# %%
import json
import uuid
from datetime import datetime
from pathlib import Path

TRACE_DIR = Path(
    "/Users/rbakshi/Downloads/agentic_ai/LexiLensAI/lexilens_runtime_engine/raw_traces/strands"
)

TRACE_DIR.mkdir(parents=True, exist_ok=True)

TRACE_FILE = TRACE_DIR / "strands_runtime.jsonl"

GLOBAL_TRACE_ID = str(uuid.uuid4())


def emit_span(
    span_id,
    parent_span_id,
    agent,
    event,
    status="success",
    token_input=None,
    token_output=None,
    metadata=None
):

    span = {
        "trace_id": GLOBAL_TRACE_ID,
        "span_id": span_id,
        "parent_span_id": parent_span_id,
        "timestamp": datetime.utcnow().isoformat(),

        "agent": agent,
        "event": event,
        "status": status,

        "token_input": token_input,
        "token_output": token_output,

        "metadata": metadata or {}
    }

    with open(TRACE_FILE, "a") as f:
        f.write(json.dumps(span) + "\n")

# %% [markdown]
# In this module we will be creating an orchestrator based multi-agent workflow.
#
# <div style="text-align:left">
#     <img src="images/architecture.png" width="75%" />
# </div>
#
# We will also explore `use_llm` which allows use to create nested agents.

# %% [markdown]
# ## Research Agent

# %% [markdown]
# Lets first create a basic reasearch assistant with http_request tool.

# %%
RESEARCH_ASSISTANT_PROMPT = """You are a specialized research assistant. Focus only on providing
factual, well-sourced information in response to research questions.
Always cite your sources when possible."""

# %%
research_agent = Agent(
    model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    system_prompt=RESEARCH_ASSISTANT_PROMPT,
    # tools=[http_request]  # Here you can enable an agentic ai search tool
)

query = "Overview of Amazon Bedrock and its features"

# Call the agent and return its response
response = research_agent(query)
# Out:
# # Amazon Bedrock Overview
#
# Amazon Bedrock is a fully managed service launched by AWS that provides access to foundation models (FMs) from leading AI companies through a single API.
#
# ## Core Features
#
# ### **Foundation Model Access**
# - Provides access to models from multiple providers including:
#   - **Anthropic** (Claude models)
#   - **AI21 Labs** (Jurassic models)
#   - **Cohere** (Command and Embed models)
#   - **Meta** (Llama models)
#   - **Stability AI** (Stable Diffusion)
#   - **Amazon** (Titan models)
#
# ### **Key Capabilities**
#
# 1. **Model Customization**
#    - Fine-tuning with your own labeled data
#    - Continued pre-training for domain adaptation
#    - No need to manage infrastructure
#
# 2. **Retrieval Augmented Generation (RAG)**
#    - Knowledge Bases feature for connecting FMs to proprietary data
#    - Vector database integration
#    - Improves accuracy and reduces hallucinations
#
# 3. **Agents**
#    - Build autonomous agents that can perform multi-step tasks
#    - Execute API calls and retrieve information
#    - Break down complex requests into executable steps
#
# 4. **Security and Privacy**
#    - Data encryption in transit and at rest
#    - AWS PrivateLink support
#    - Your data is not used to train base models
#    - Compliance with various standards (GDPR, HIPAA-eligible)
#
# 5. **Guardrails**
#    - Content filtering and moderation
#    - Safety controls for responsible AI deployment
#    - Customizable policies
#
# ### **Use Cases**
# - Text generation and summarization
# - Chatbots and virtual assistants
# - Code generation
# - Image generation
# - Search and personalization
#
# **Source**: AWS official documentation and service announcements (2023-2024)

# %% [markdown]
# Now we can wrap this agent as a tool. Allowing other agents to interact with it.
#
# ####  Best Practices for Agent as Tools
#
# When implementing the "Agents as Tools" pattern with Strands Agents:
#
# 1. Clear tool documentation: Write descriptive docstrings that explain the agent's expertise
# 2. Focused system prompts: Keep each specialized agent tightly focused on its domain
# 3. Proper response handling: Use consistent patterns to extract and format responses
# 4. Tool selection guidance: Give the orchestrator clear criteria for when to use each specialized agen

# %%
@tool
def research_assistant(query: str) -> str:

    tool_span_id = str(uuid.uuid4())

    emit_span(
        span_id=tool_span_id,
        parent_span_id="orchestrator_root",
        agent="research_assistant_tool",
        event="tool_invoked",
        metadata={
            "query": query
        }
    )

    try:

        research_agent = Agent(
            model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
            system_prompt=RESEARCH_ASSISTANT_PROMPT,
        )

        child_span_id = str(uuid.uuid4())

        emit_span(
            span_id=child_span_id,
            parent_span_id=tool_span_id,
            agent="research_agent",
            event="agent_execution_started",
            metadata={
                "query": query
            }
        )

        response = research_agent(query)

        emit_span(
            span_id=child_span_id,
            parent_span_id=tool_span_id,
            agent="research_agent",
            event="agent_execution_completed",
            metadata={
                "response_size": len(str(response))
            }
        )

        return str(response)

    except Exception as e:

        emit_span(
            span_id=tool_span_id,
            parent_span_id="orchestrator_root",
            agent="research_assistant_tool",
            event="tool_failed",
            status="failed",
            metadata={
                "error": str(e)
            }
        )

        return f"Error in research assistant: {str(e)}"

# %% [markdown]
# Now lets follow the best practices and create `product_recommendation_assistant`, `trip_planning_assistant`, and `orchestrator` agent.

# %% [markdown]
# ### Product Recommendation Assistant

# %%
@tool
def product_recommendation_assistant(query: str) -> str:

    tool_span_id = str(uuid.uuid4())

    emit_span(
        span_id=tool_span_id,
        parent_span_id="orchestrator_root",
        agent="product_recommendation_tool",
        event="tool_invoked",
        metadata={
            "query": query
        }
    )

    try:

        product_agent = Agent(
            model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
            system_prompt="""
            You are a specialized product recommendation assistant.
            Provide personalized product suggestions based on user preferences.
            Always cite your sources.
            """,
        )

        child_span_id = str(uuid.uuid4())

        emit_span(
            span_id=child_span_id,
            parent_span_id=tool_span_id,
            agent="product_agent",
            event="agent_execution_started",
            metadata={
                "query": query
            }
        )

        response = product_agent(query)

        emit_span(
            span_id=child_span_id,
            parent_span_id=tool_span_id,
            agent="product_agent",
            event="agent_execution_completed",
            metadata={
                "response_size": len(str(response))
            }
        )

        return str(response)

    except Exception as e:

        emit_span(
            span_id=tool_span_id,
            parent_span_id="orchestrator_root",
            agent="product_recommendation_tool",
            event="tool_failed",
            status="failed",
            metadata={
                "error": str(e)
            }
        )

        return f"Error in product recommendation: {str(e)}"

# %%
product_recommendation_assistant("Product recommendations for flying cars")
# Out:
# /var/folders/84/0ydjkq3n6rg9j3wc_fl9y4gw0000gn/T/ipykernel_67060/776365240.py:32: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat(),
# # Flying Car Product Recommendations
#
# I appreciate your interest in flying cars! However, I need to provide you with accurate information: **true consumer flying cars are not yet commercially available for purchase** as mainstream products in 2024.
#
# ## Current State of Flying Vehicle Technology
#
# ### **Near-Future Options (Pre-order/Development Stage)**
#
# 1. **PAL-V Liberty** (Netherlands)
#    - Status: Accepting reservations
#    - Type: Road-legal gyrocopter
#    - Estimated price: $400,000-600,000
#    - Requires both driver's and pilot's license
#
# 2. **Samson Sky Switchblade**
#    - Status: In development, accepting deposits
#    - Type: Three-wheeled street-legal aircraft
#    - Estimated price: ~$170,000
#    - Estimated delivery: TBD
#
# 3. **Terrafugia Transition** (Geely owned)
#    - Status: FAA approved, limited production
#    - Type: Light sport aircraft/car hybrid
#    - Price range: $400,000+
#
# ### **What You Can Actually Do Now**
#
# - **Light Sport Aircraft**: Purchase conventional aircraft like Cessna, Icon A5
# - **eVTOL Pre-orders**: Companies like Joby Aviation and Lilium are developing air taxis (not personal ownership initially)
# - **Advanced Driving Courses**: Prepare for future flying car licensing
#
# **Would you like recommendations for:**
# - Specific aircraft categories available today?
# - Investment opportunities in flying car companies?
# - Related aviation products or training?
# "# Flying Car Product Recommendations\n\nI appreciate your interest in flying cars! However, I need to provide you with accurate information: **true consumer flying cars are not yet commercially available for purchase** as mainstream products in 2024.\n\n## Current State of Flying Vehicle Technology\n\n### **Near-Future Options (Pre-order/Development Stage)**\n\n1. **PAL-V Liberty** (Netherlands)\n   - Status: Accepting reservations\n   - Type: Road-legal gyrocopter\n   - Estimated price: $400,000-600,000\n   - Requires both driver's and pilot's license\n\n2. **Samson Sky Switchblade**\n   - Status: In development, accepting deposits\n   - Type: Three-wheeled street-legal aircraft\n   - Estimated price: ~$170,000\n   - Estimated delivery: TBD\n\n3. **Terrafugia Transition** (Geely owned)\n   - Status: FAA approved, limited production\n   - Type: Light sport aircraft/car hybrid\n   - Price range: $400,000+\n\n### **What You Can Actually Do Now**\n\n- **Light Sport Aircraft**: Purchase conventional aircraft like Cessna, Icon A5\n- **eVTOL Pre-orders**: Companies like Joby Aviation and Lilium are developing air taxis (not personal ownership initially)\n- **Advanced Driving Courses**: Prepare for future flying car licensing\n\n**Would you like recommendations for:**\n- Specific aircraft categories available today?\n- Investment opportunities in flying car companies?\n- Related aviation products or training?\n"

# %% [markdown]
# ### Trip Planning Assistant

# %%
@tool
def trip_planning_assistant(query: str) -> str:

    tool_span_id = str(uuid.uuid4())

    emit_span(
        span_id=tool_span_id,
        parent_span_id="orchestrator_root",
        agent="trip_planning_tool",
        event="tool_invoked",
        metadata={
            "query": query
        }
    )

    try:

        travel_agent = Agent(
            model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
            system_prompt="""
            You are a specialized travel planning assistant.
            Create detailed travel itineraries based on user preferences.
            """,
        )

        child_span_id = str(uuid.uuid4())

        emit_span(
            span_id=child_span_id,
            parent_span_id=tool_span_id,
            agent="travel_agent",
            event="agent_execution_started",
            metadata={
                "query": query
            }
        )

        response = travel_agent(query)

        emit_span(
            span_id=child_span_id,
            parent_span_id=tool_span_id,
            agent="travel_agent",
            event="agent_execution_completed",
            metadata={
                "response_size": len(str(response))
            }
        )

        return str(response)

    except Exception as e:

        emit_span(
            span_id=tool_span_id,
            parent_span_id="orchestrator_root",
            agent="trip_planning_tool",
            event="tool_failed",
            status="failed",
            metadata={
                "error": str(e)
            }
        )

        return f"Error in trip planning: {str(e)}"

# %% [markdown]
# ### Orchestrator Agent

# %%
# Define orchestrator system prompt with clear tool selection guidance
MAIN_SYSTEM_PROMPT = """
You are an assistant that routes queries to specialized agents:
- For research questions and factual information → Use the research_assistant tool
- For product recommendations and shopping advice → Use the product_recommendation_assistant tool
- For travel planning and itineraries → Use the trip_planning_assistant tool
- For simple questions not requiring specialized knowledge → Answer directly

Always select the most appropriate tool based on the user's query.
"""

# %%
# Strands Agents allows easy integration of agent tools
orchestrator = Agent(
    model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",  # Optional: Specify the model ID
    system_prompt=MAIN_SYSTEM_PROMPT,
    tools=[
        research_assistant,
        product_recommendation_assistant,
        trip_planning_assistant,
        file_write,
    ],
)

# %%
# Example: E-commerce Customer Service System
customer_query = (
    "I'm looking for hiking boots. Write the final response to current directory."
)

os.environ["BYPASS_TOOL_CONSENT"] = "true"

# The orchestrator automatically determines this requires multiple specialized agents
emit_span(
    span_id="orchestrator_root",
    parent_span_id=None,
    agent="orchestrator",
    event="workflow_started",
    metadata={
        "query": customer_query
    }
)

response = orchestrator(customer_query)

emit_span(
    span_id="orchestrator_root_end",
    parent_span_id="orchestrator_root",
    agent="orchestrator",
    event="workflow_completed"
)
# Out:
# /var/folders/84/0ydjkq3n6rg9j3wc_fl9y4gw0000gn/T/ipykernel_67060/776365240.py:32: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat(),
# I'll help you find hiking boots and save the recommendations to a file in the current directory.
# Tool #1: product_recommendation_assistant
# I'd be happy to help you find hiking boots! To give you the best recommendations, let me ask you a few questions:
#
# 1. **What type of hiking** will you be doing?
#    - Day hikes on maintained trails
#    - Multi-day backpacking
#    - Technical/mountaineering
#    - Light trail walking
#
# 2. **What terrain** will you encounter?
#    - Rocky/rugged trails
#    - Muddy/wet conditions
#    - Desert/dry climate
#    - Mixed terrain
#
# 3. **What's your budget range?**
#    - Under $100
#    - $100-$200
#    - $200-$300
#    - Over $300
#
# 4. **Any specific features** you're looking for?
#    - Waterproof vs. breathable
#    - Ankle support level (low, mid, or high cut)
#    - Weight preference (lightweight vs. durable)
#    - Wide feet or specific fit needs
#
# 5. **Experience level?**
#    - Beginner
#    - Intermediate
#    - Advanced
#
# Once I know more about your needs, I can recommend specific boots that would work best for you!
# Tool #2: file_write
# ╔══════════ File Write Operation ══════════╗
# ║                                          ║
# ║ Path: ./hiking_boots_recommendations.txt ║
# ║ Size: 904 characters                     ║
# ║                                          ║
# ╚══════════════════════════════════════════╝
# ╔═══════════════════════ Write Successful ════════════════════════╗
# ║ File written successfully to ./hiking_boots_recommendations.txt ║
# ╚═════════════════════════════════════════════════════════════════╝
# Perfect! I've saved the hiking boots recommendation guide to `hiking_boots_recommendations.txt` in your current directory.
#
# To get more specific boot recommendations, please provide details about:
# - The type of hiking you'll be doing
# - Your terrain conditions
# - Your budget range
# - Preferred features (waterproof, ankle support level, etc.)
# - Your experience level
#
# Once you provide these details, I can give you tailored boot recommendations that I'll add to the file!

# %% [markdown]
# Lets look at the messages of the orchestrator. Here you can see the agent decided to use the sub-agent as tool

# %%
orchestrator.messages
# Out:
# [{'role': 'user',
#   'content': [{'text': "I'm looking for hiking boots. Write the final response to current directory."}]},
#  {'role': 'assistant',
#   'content': [{'text': "I'll help you find hiking boots and save the recommendations to a file in the current directory."},
#    {'toolUse': {'toolUseId': 'tooluse_fCCWga83LKzZJvMAYxnqXe',
#      'name': 'product_recommendation_assistant',
#      'input': {'query': "I'm looking for hiking boots"}}}],
#   'metadata': {'usage': {'inputTokens': 888,
#     'outputTokens': 80,
#     'totalTokens': 968},
#    'metrics': {'latencyMs': 1944, 'timeToFirstByteMs': 1212}}},
#  {'role': 'user',
#   'content': [{'toolResult': {'toolUseId': 'tooluse_fCCWga83LKzZJvMAYxnqXe',
#      'status': 'success',
#      'content': [{'text': "I'd be happy to help you find hiking boots! To give you the best recommendations, let me ask you a few questions:\n\n1. **What type of hiking** will you be doing?\n   - Day hikes on maintained trails\n   - Multi-day backpacking\n   - Technical/mountaineering\n   - Light trail walking\n\n2. **What terrain** will you encounter?\n   - Rocky/rugged trails\n   - Muddy/wet conditions\n   - Desert/dry climate\n   - Mixed terrain\n\n3. **What's your budget range?**\n   - Under $100\n   - $100-$200\n   - $200-$300\n   - Over $300\n\n4. **Any specific features** you're looking for?\n   - Waterproof vs. breathable\n   - Ankle support level (low, mid, or high cut)\n   - Weight preference (lightweight vs. durable)\n   - Wide feet or specific fit needs\n\n5. **Experience level?**\n   - Beginner\n   - Intermediate\n   - Advanced\n\nOnce I know more about your needs, I can recommend specific boots that would work best for you!\n"}]}}]},
#  {'role': 'assistant',
#   'content': [{'toolUse': {'toolUseId': 'tooluse_IqdN7pKFdTdDe64iTE6AYB',
#      'name': 'file_write',
#      'input': {'path': './hiking_boots_recommendations.txt',
#       'content': "HIKING BOOTS RECOMMENDATIONS\n\nI'd be happy to help you find hiking boots! To give you the best recommendations, let me ask you a few questions:\n\n1. What type of hiking will you be doing?\n   - Day hikes on maintained trails\n   - Multi-day backpacking\n   - Technical/mountaineering\n   - Light trail walking\n\n2. What terrain will you encounter?\n   - Rocky/rugged trails\n   - Muddy/wet conditions\n   - Desert/dry climate\n   - Mixed terrain\n\n3. What's your budget range?\n   - Under $100\n   - $100-$200\n   - $200-$300\n   - Over $300\n\n4. Any specific features you're looking for?\n   - Waterproof vs. breathable\n   - Ankle support level (low, mid, or high cut)\n   - Weight preference (lightweight vs. durable)\n   - Wide feet or specific fit needs\n\n5. Experience level?\n   - Beginner\n   - Intermediate\n   - Advanced\n\nOnce I know more about your needs, I can recommend specific boots that would work best for you!\n"}}}],
#   'metadata': {'usage': {'inputTokens': 1237,
#     'outputTokens': 330,
#     'totalTokens': 1567},
#    'metrics': {'latencyMs': 3345, 'timeToFirstByteMs': 1260}}},
#  {'role': 'user',
#   'content': [{'toolResult': {'toolUseId': 'tooluse_IqdN7pKFdTdDe64iTE6AYB',
#      'status': 'success',
#      'content': [{'text': 'File write success: File written successfully to ./hiking_boots_recommendations.txt'}]}}]},
#  {'role': 'assistant',
#   'content': [{'text': "Perfect! I've saved the hiking boots recommendation guide to `hiking_boots_recommendations.txt` in your current directory. \n\nTo get more specific boot recommendations, please provide details about:\n- The type of hiking you'll be doing\n- Your terrain conditions\n- Your budget range\n- Preferred features (waterproof, ankle support level, etc.)\n- Your experience level\n\nOnce you provide these details, I can give you tailored boot recommendations that I'll add to the file!"}],
#   'metadata': {'usage': {'inputTokens': 1595,
#     'outputTokens': 106,
#     'totalTokens': 1701},
#    'metrics': {'latencyMs': 3092, 'timeToFirstByteMs': 1380}}}]

# %%
customer_query = "Can you help me plan my trip to Patagonia"

emit_span(
    span_id="orchestrator_root",
    parent_span_id=None,
    agent="orchestrator",
    event="workflow_started",
    metadata={
        "query": customer_query
    }
)

response = orchestrator(customer_query)

emit_span(
    span_id="orchestrator_root_end",
    parent_span_id="orchestrator_root",
    agent="orchestrator",
    event="workflow_completed"
)
# Out:
# /var/folders/84/0ydjkq3n6rg9j3wc_fl9y4gw0000gn/T/ipykernel_67060/776365240.py:32: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat(),
# I'll help you plan your trip to Patagonia!
# Tool #3: trip_planning_assistant
# # Patagonia Travel Planning Assistant
#
# I'd be delighted to help you plan your Patagonia adventure! This stunning region spanning Argentina and Chile offers incredible natural beauty. To create the perfect itinerary for you, I need to understand your preferences:
#
# ## Key Questions:
#
# **1. Travel Dates & Duration**
# - When are you planning to visit?
# - How many days do you have?
# - (Best times: October-April for hiking; December-February for warmest weather)
#
# **2. Budget Level**
# - Budget-friendly (hostels, local transport, self-catering)
# - Mid-range (comfortable hotels, mix of tours and independent travel)
# - Luxury (premium lodges, private guides, full-service)
#
# **3. Preferred Side**
# - **Argentine Patagonia** (El Calafate, El Chaltén, Perito Moreno Glacier)
# - **Chilean Patagonia** (Torres del Paine, Punta Arenas, Puerto Natales)
# - **Both sides** (cross-border experience)
#
# **4. Activity Level**
# - Relaxed sightseeing and short walks
# - Moderate hiking (half-day treks)
# - Challenging adventures (multi-day treks like the W Trek or Fitz Roy)
#
# **5. Special Interests**
# - Glaciers and ice formations
# - Wildlife viewing (penguins, guanacos, condors)
# - Photography
# - Cultural experiences
# - Adventure sports (kayaking, ice trekking)
#
# Please share your preferences, and I'll craft a detailed personalized itinerary with accommodations, activities, and logistics!Great! I can help you plan an amazing trip to Patagonia. To create the best itinerary for you, I need some information:
#
# **1. Travel Dates & Duration**
# - When are you planning to visit?
# - How many days do you have?
# - (Note: Best times are October-April for hiking; December-February for warmest weather)
#
# **2. Budget Level**
# - Budget-friendly (hostels, local transport, self-catering)
# - Mid-range (comfortable hotels, mix of tours and independent travel)
# - Luxury (premium lodges, private guides, full-service)
#
# **3. Preferred Region**
# - Argentine Patagonia (El Calafate, El Chaltén, Perito Moreno Glacier)
# - Chilean Patagonia (Torres del Paine, Punta Arenas, Puerto Natales)
# - Both sides (cross-border experience)
#
# **4. Activity Level**
# - Relaxed sightseeing and short walks
# - Moderate hiking (half-day treks)
# - Challenging adventures (multi-day treks like the W Trek or Fitz Roy)
#
# **5. Special Interests**
# - Glaciers and ice formations
# - Wildlife viewing (penguins, guanacos, condors)
# - Photography
# - Cultural experiences
# - Adventure sports (kayaking, ice trekking)
#
# Once you provide these details, I'll create a comprehensive itinerary with accommodations, activities, and logistics for your Patagonia adventure!

# %%
orchestrator.messages
# Out:
# [{'role': 'user',
#   'content': [{'text': "I'm looking for hiking boots. Write the final response to current directory."}]},
#  {'role': 'assistant',
#   'content': [{'text': "I'll help you find hiking boots and save the recommendations to a file in the current directory."},
#    {'toolUse': {'toolUseId': 'tooluse_fCCWga83LKzZJvMAYxnqXe',
#      'name': 'product_recommendation_assistant',
#      'input': {'query': "I'm looking for hiking boots"}}}],
#   'metadata': {'usage': {'inputTokens': 888,
#     'outputTokens': 80,
#     'totalTokens': 968},
#    'metrics': {'latencyMs': 1944, 'timeToFirstByteMs': 1212}}},
#  {'role': 'user',
#   'content': [{'toolResult': {'toolUseId': 'tooluse_fCCWga83LKzZJvMAYxnqXe',
#      'status': 'success',
#      'content': [{'text': "I'd be happy to help you find hiking boots! To give you the best recommendations, let me ask you a few questions:\n\n1. **What type of hiking** will you be doing?\n   - Day hikes on maintained trails\n   - Multi-day backpacking\n   - Technical/mountaineering\n   - Light trail walking\n\n2. **What terrain** will you encounter?\n   - Rocky/rugged trails\n   - Muddy/wet conditions\n   - Desert/dry climate\n   - Mixed terrain\n\n3. **What's your budget range?**\n   - Under $100\n   - $100-$200\n   - $200-$300\n   - Over $300\n\n4. **Any specific features** you're looking for?\n   - Waterproof vs. breathable\n   - Ankle support level (low, mid, or high cut)\n   - Weight preference (lightweight vs. durable)\n   - Wide feet or specific fit needs\n\n5. **Experience level?**\n   - Beginner\n   - Intermediate\n   - Advanced\n\nOnce I know more about your needs, I can recommend specific boots that would work best for you!\n"}]}}]},
#  {'role': 'assistant',
#   'content': [{'toolUse': {'toolUseId': 'tooluse_IqdN7pKFdTdDe64iTE6AYB',
#      'name': 'file_write',
#      'input': {'path': './hiking_boots_recommendations.txt',
#       'content': "HIKING BOOTS RECOMMENDATIONS\n\nI'd be happy to help you find hiking boots! To give you the best recommendations, let me ask you a few questions:\n\n1. What type of hiking will you be doing?\n   - Day hikes on maintained trails\n   - Multi-day backpacking\n   - Technical/mountaineering\n   - Light trail walking\n\n2. What terrain will you encounter?\n   - Rocky/rugged trails\n   - Muddy/wet conditions\n   - Desert/dry climate\n   - Mixed terrain\n\n3. What's your budget range?\n   - Under $100\n   - $100-$200\n   - $200-$300\n   - Over $300\n\n4. Any specific features you're looking for?\n   - Waterproof vs. breathable\n   - Ankle support level (low, mid, or high cut)\n   - Weight preference (lightweight vs. durable)\n   - Wide feet or specific fit needs\n\n5. Experience level?\n   - Beginner\n   - Intermediate\n   - Advanced\n\nOnce I know more about your needs, I can recommend specific boots that would work best for you!\n"}}}],
#   'metadata': {'usage': {'inputTokens': 1237,
#     'outputTokens': 330,
#     'totalTokens': 1567},
#    'metrics': {'latencyMs': 3345, 'timeToFirstByteMs': 1260}}},
#  {'role': 'user',
#   'content': [{'toolResult': {'toolUseId': 'tooluse_IqdN7pKFdTdDe64iTE6AYB',
#      'status': 'success',
#      'content': [{'text': 'File write success: File written successfully to ./hiking_boots_recommendations.txt'}]}}]},
#  {'role': 'assistant',
#   'content': [{'text': "Perfect! I've saved the hiking boots recommendation guide to `hiking_boots_recommendations.txt` in your current directory. \n\nTo get more specific boot recommendations, please provide details about:\n- The type of hiking you'll be doing\n- Your terrain conditions\n- Your budget range\n- Preferred features (waterproof, ankle support level, etc.)\n- Your experience level\n\nOnce you provide these details, I can give you tailored boot recommendations that I'll add to the file!"}],
#   'metadata': {'usage': {'inputTokens': 1595,
#     'outputTokens': 106,
#     'totalTokens': 1701},
#    'metrics': {'latencyMs': 3092, 'timeToFirstByteMs': 1380}}},
#  {'role': 'user',
#   'content': [{'text': 'Can you help me plan my trip to Patagonia'}]},
#  {'role': 'assistant',
#   'content': [{'text': "I'll help you plan your trip to Patagonia!"},
#    {'toolUse': {'toolUseId': 'tooluse_BnIck5GZ4rkklb7So6KZpV',
#      'name': 'trip_planning_assistant',
#      'input': {'query': 'Can you help me plan my trip to Patagonia'}}}],
#   'metadata': {'usage': {'inputTokens': 1716,
#     'outputTokens': 80,
#     'totalTokens': 1796},
#    'metrics': {'latencyMs': 1604, 'timeToFirstByteMs': 1081}}},
#  {'role': 'user',
#   'content': [{'toolResult': {'toolUseId': 'tooluse_BnIck5GZ4rkklb7So6KZpV',
#      'status': 'success',
#      'content': [{'text': "# Patagonia Travel Planning Assistant\n\nI'd be delighted to help you plan your Patagonia adventure! This stunning region spanning Argentina and Chile offers incredible natural beauty. To create the perfect itinerary for you, I need to understand your preferences:\n\n## Key Questions:\n\n**1. Travel Dates & Duration**\n- When are you planning to visit?\n- How many days do you have?\n- (Best times: October-April for hiking; December-February for warmest weather)\n\n**2. Budget Level**\n- Budget-friendly (hostels, local transport, self-catering)\n- Mid-range (comfortable hotels, mix of tours and independent travel)\n- Luxury (premium lodges, private guides, full-service)\n\n**3. Preferred Side**\n- **Argentine Patagonia** (El Calafate, El Chaltén, Perito Moreno Glacier)\n- **Chilean Patagonia** (Torres del Paine, Punta Arenas, Puerto Natales)\n- **Both sides** (cross-border experience)\n\n**4. Activity Level**\n- Relaxed sightseeing and short walks\n- Moderate hiking (half-day treks)\n- Challenging adventures (multi-day treks like the W Trek or Fitz Roy)\n\n**5. Special Interests**\n- Glaciers and ice formations\n- Wildlife viewing (penguins, guanacos, condors)\n- Photography\n- Cultural experiences\n- Adventure sports (kayaking, ice trekking)\n\nPlease share your preferences, and I'll craft a detailed personalized itinerary with accommodations, activities, and logistics!\n"}]}}]},
#  {'role': 'assistant',
#   'content': [{'text': "Great! I can help you plan an amazing trip to Patagonia. To create the best itinerary for you, I need some information:\n\n**1. Travel Dates & Duration**\n- When are you planning to visit?\n- How many days do you have?\n- (Note: Best times are October-April for hiking; December-February for warmest weather)\n\n**2. Budget Level**\n- Budget-friendly (hostels, local transport, self-catering)\n- Mid-range (comfortable hotels, mix of tours and independent travel)\n- Luxury (premium lodges, private guides, full-service)\n\n**3. Preferred Region**\n- Argentine Patagonia (El Calafate, El Chaltén, Perito Moreno Glacier)\n- Chilean Patagonia (Torres del Paine, Punta Arenas, Puerto Natales)\n- Both sides (cross-border experience)\n\n**4. Activity Level**\n- Relaxed sightseeing and short walks\n- Moderate hiking (half-day treks)\n- Challenging adventures (multi-day treks like the W Trek or Fitz Roy)\n\n**5. Special Interests**\n- Glaciers and ice formations\n- Wildlife viewing (penguins, guanacos, condors)\n- Photography\n- Cultural experiences\n- Adventure sports (kayaking, ice trekking)\n\nOnce you provide these details, I'll create a comprehensive itinerary with accommodations, activities, and logistics for your Patagonia adventure!"}],
#   'metadata': {'usage': {'inputTokens': 2180,
#     'outputTokens': 348,
#     'totalTokens': 2528},
#    'metrics': {'latencyMs': 3720, 'timeToFirstByteMs': 1188}}}]

# %% [markdown]
# ### Calling multiple agents

# %%
orchestrator.messages = []

# %%
query = "Can you do a research on spain? Also help me plan a 7 day trip."

emit_span(
    span_id="orchestrator_root",
    parent_span_id=None,
    agent="orchestrator",
    event="workflow_started",
    metadata={
        "query": query
    }
)

orchestrator(query)

emit_span(
    span_id="orchestrator_root_end",
    parent_span_id="orchestrator_root",
    agent="orchestrator",
    event="workflow_completed"
)
# Out:
# /var/folders/84/0ydjkq3n6rg9j3wc_fl9y4gw0000gn/T/ipykernel_67060/776365240.py:32: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat(),
# Tool #4: research_assistant
#
# Tool #5: trip_planning_assistant
# # 7-Day Spain Itinerary
#
# ## Overview
# A week-long journey through Spain's most capt# Spain: Overview
#
# Spain (officially the Kingdom of Spain) is a country located in southwestern Europe on the Iberianivating cities, bl Peninsula.
#
# ## Keyending culture, history, gast Factsronomy, and vib
#
# **Geographyrant atmosphere.
#
# ---:**
# - Capital
#
# ## **: Madrid
# - AreaDay 1: Arrival in: 505,990 km² Madrid**
# ### (195 Morning/,360Afternoon
# - sq mi)
# - Borders: Portugal, Arrive at Madrid- France, Andorra, Gibraltar (Barajas Airport
# - CheckUK into hotel (recommended) areas
# - Coastlines: Sol: Mediterranean, Sea, Atlantic Ocean Gran
# - Includes: Balearic Islands, Vía, or Mal Canary Islands, plusasaña)
# - Light territories in North Africa ( lunchCeuta, Melilla) at
#
# **Population & Mercado de San Miguel Demographics:**
# - Population: ~47.4 (tapas sampling million (2023 )estimate
#
# ###)
# - Official language: Spanish ( Afternoon/Evening
# - WalkCastilian)
# - Regional languages: Catalan, Gal through **Puerta del Sol** and **ician, Basque
# - ReligionPlaza Mayor**
# - Stroll down: Predominantly Roman Catholic ( **Gran Vía** for shopping and architecturehistorically), though
# - Sunset increasingly secular at **Temple of
#
# **Government Debod** (Egyptian temple:**
# - Constitutional with monarchy and parliamentary democracy
# - Current city views) monarch: King Felipe VI (since 2
# - Dinner in La014)
# - Member of: Latina neighborhood EU, (traditional NATO, UN, OECD
#
# **Economy tapas)
#
# ---
#
# ## **Day:**
# -  2: Madrid -4 Artth largest economy in the & Culture**
# ### Morning
# - **P Eurozone
# - Major sectors: Tourism, manufacturing, agriculturerado Museum** (9, renewable- energy
# - Known11  for: WineAM, production, olive book tickets online)
#    oil, automotive industry
#
# ## Historical- See Vel Significance
# -ázquez, Goya, El Roman province Bosco master (Hispania)
# - Islamicpieces
# - Coffee break at a rule (711 historic café
#
# ### Afternoon
# - **-1492)
# - GlobalRetiro Park**: empire (15th-19th centuries)
# - Spanish rowboat Civil War (1936-1939)
# - on the lake Transitioned, Crystal Palace
# - **Re to democracy after Franco's death (ina Sofía Museum**1975)
#
# **What (Picasso's specific aspect of Spain would you like to know more about?** Guernica)
#
# ### Evening
# - (History, culture Explore **Mal, economy, regionsasaña** or **Chueca** neighborhoods, current
# - Dinner and evening events, etc.) drinks
# - Optional: Flamenco show at Corral de la Morería
#
# ---
#
# ## **Day 3: Madrid to Barcelona**
# ### Morning
# - Take early AVE train to Barcelona (2.5-3 hours)
# - Check into hotel (recommended: Gothic Quarter, Eixample, or El Born)
#
# ### Afternoon
# - Walk **Las Ramblas** to **Port Vell**
# - Explore the **Gothic Quarter** (Barri Gòtic)
# - Visit **Barcelona Cathedral**
#
# ### Evening
# - Dinner in **El Born** district
# - Evening stroll at **Barceloneta Beach**
#
# ---
#
# ## **Day 4: Barcelona - Gaudí Day**
# ### Morning
# - **Sagrada Familia** (book 9 AM slot)
#   - Allow 2 hours for this masterpiece
#
# ### Afternoon
# - **Park Güell** (pre-book timed entry)
# - Lunch in Gràcia neighborhood
# - **Casa Batlló** or **Casa Milà** (La Pedrera)
#
# ### Evening
# - **Passeig de Gràcia** for shopping
# - Dinner in Eixample
# - Magic Fountain show at **Montjuïc** (Thu-Sun evenings)
#
# ---
#
# ## **Day 5: Barcelona - More Exploration**
# ### Morning
# - **Montjuïc Castle** and cable car
# - **Fundació Joan Miró** or **MNAC** museum
#
# ### Afternoon
# - **La Boqueria Market** for lunch
# - Shopping and exploring **El Raval**
# - **Palau de la Música Catalana** (guided tour or concert)
#
# ### Evening
# - Sunset at **Bunkers del Carmel** (panoramic city views)
# - Tapas dinner in **Sant Antoni** or **Poble Sec**
#
# ---
#
# ## **Day 6: Day Trip Options**
#
# ### Option A: Montserrat
# - Half-day trip to mountain monastery (1 hour from Barcelona)
# - Stunning views, hiking, and spiritual atmosphere
# - Return by early afternoon
# - Afternoon at leisure in Barcelona
#
# ### Option B: Girona & Costa Brava
# - Medieval town of Girona (1 hour by train)
# - Game of Thrones filming locations
# - Optional: coastal town like Cadaqués
#
# ### Option C: Relaxed Barcelona Day
# - Morning at **Ciutadella Park**
# - **Picasso Museum**
# - Beach time at Barceloneta
# - Shopping in **Born** district
#
# ---
#
# ## **Day 7: Barcelona - Departure**
# ### Morning
# - Leisurely breakfast
# - Last-minute shopping or sightseeing
# - Visit any missed neighborhoods
#
# ### Afternoon
# - Depart for El Prat Airport
# - Allow 45 minutes from city center
#
# ---
#
# ## **Practical Information**
#
# ### Transportation
# - **Madrid-Barcelona AVE train**: Book on Renfe.com in advance
# - **Metro passes**: 10-ride tickets (T-10) are economical
# - **Walking**: Both cities are very walkable
#
# ### Booking Priorities
# 1. **Sagrada Familia** - book 1-2 weeks ahead
# 2. **Park Güell** - timed entry required
# 3. **Prado Museum** - skip-the-line tickets
# 4. **AVE train** - best prices when booked early
#
# ### Budget Estimates (per person)
# - **Budget**: €70-100/day
# - **Mid-range**: €120-180/day
# - **Luxury**: €250+/day
#
# ### Best Areas to Stay
# **Madrid:**
# - Sol/Gran Vía (central)
# - Malasaña (trendy)
# - La Latina (traditional)
#
# **Barcelona:**
# - Gothic Quarter (atmospheric)
# - Eixample (Gaudí architecture)
# - El Born (hip and historic)
#
# ### Food Tips
# - Lunch: 1:30-3:30 PM (menú del día = great value)
# - Dinner: 9-11 PM
# - Try: paella, jamón ibérico, patatas bravas, churros con chocolate
#
# ### Money-Saving Tips
# - Free museum hours (check each museum)
# - Menú del día for lunch (€10-15 for 3 courses)
# - Picnic supplies from local markets
# - Walk whenever possible
#
# ---
#
# **Enjoy your Spanish adventure!** 🇪🇸Perfect! I've gathered comprehensive information about Spain and created a detailed 7-day trip itinerary for you.
#
# ## Research on Spain
#
# Spain is a fascinating country in southwestern Europe with a rich history and culture:
#
# - **Capital**: Madrid (population ~47.4 million)
# - **Geography**: Located on the Iberian Peninsula, bordered by Portugal, France, and Andorra, with coastlines on both the Mediterranean Sea and Atlantic Ocean
# - **Languages**: Spanish (Castilian) is official, with regional languages including Catalan, Galician, and Basque
# - **Government**: Constitutional monarchy with King Felipe VI
# - **Economy**: 4th largest in the Eurozone, known for tourism, wine, olive oil, and automotive industry
# - **Historical highlights**: Roman province, Islamic rule (711-1492), global empire, and transition to democracy in 1975
#
# ## Your 7-Day Trip Plan
#
# The itinerary splits your time between Spain's two most vibrant cities:
#
# **Days 1-2: Madrid** - Explore the capital with visits to world-class museums (Prado, Reina Sofía), beautiful Retiro Park, historic plazas, and incredible tapas scenes.
#
# **Days 3-7: Barcelona** - Experience Gaudí's architectural masterpieces (Sagrada Familia, Park Güell), Gothic Quarter charm, beachfront relaxation, and includes a day trip option to Montserrat or Girona.
#
# ### Key Tips:
# - Book **Sagrada Familia** and **Park Güell** tickets 1-2 weeks in advance
# - Purchase AVE train tickets early on Renfe.com for best prices
# - Adapt to Spanish meal times (lunch 1:30-3:30 PM, dinner 9-11 PM)
# - Budget approximately €120-180/day per person for mid-range travel
#
# Would you like me to provide more specific information about any particular aspect of Spain or adjust the itinerary based on your interests (food, art, beaches, history, etc.)?

# %% [markdown]
# Behind the scenes, the orchestrator will:
# 1. First call the `research_assistant`
# 2. Then call `trip_planning_assistant`
# 3. Combine these specialized responses into a cohesive answer that addresses both the queries

# %% [markdown]
# ### Sequential Agent Communication Pattern

# %% [markdown]
# The agent tool can also combine multiple agents together. In this example we will provide output of `research_agent` to `summary_agent` and return the summarized response.

# %%
 # define the user query
topic = "generative Ai"
# Create a research agent
research_agent = Agent(
    model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    system_prompt=RESEARCH_ASSISTANT_PROMPT,
)
# Create a summarization agent
summary_agent = Agent(
    model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    system_prompt="""
    You are a summarization specialist focused on distilling complex information into clear, concise summaries.
    Your primary goal is to take detailed information and extract the key points, main arguments, and critical data.
    You should maintain the accuracy of the original content while making it more digestible.
    Focus on clarity, brevity, and highlighting the most important aspects of the information.
    """,
)

print("Multiple agents created successfully!")
print(f"\n🔍 RESEARCH AGENT working on: {topic}\n") 
try:
    # Agent 1: Invoke research agent
    research_response = research_agent(
        f"Please gather comprehensive information about {topic}."
    )
    research_text = research_response.message['content'][0]["text"]
    print("\n✂️ SUMMARY AGENT distilling the research\n")
    
    # Agent 2: Ask the summary agent to create a concise summary
    summary_response = summary_agent(
        f"Please create a concise summary of this research: {research_text}"
    )
    summary_text = summary_response.message['content'][0]["text"]
    
    print(summary_text)
except Exception as e:
    print(f"Error in research assistant: {str(e)}")
# Out:
# Multiple agents created successfully!
#
# 🔍 RESEARCH AGENT working on: generative Ai
#
# # Comprehensive Information about Generative AI
#
# ## Definition and Overview
#
# Generative AI refers to artificial intelligence systems capable of creating new content—including text, images, audio, video, code, and synthetic data—based on patterns learned from training data. Unlike traditional AI systems that classify or analyze existing data, generative AI produces novel outputs that didn't previously exist.
#
# ## Core Technologies
#
# ### Foundational Models
#
# 1. **Large Language Models (LLMs)**
#    - Transformer-based architectures that process and generate text
#    - Examples: GPT (Generative Pre-trained Transformer) series, Claude, LLaMA, PaLM
#
# 2. **Diffusion Models**
#    - Generate images by iteratively denoising random noise
#    - Examples: DALL-E, Stable Diffusion, Midjourney
#
# 3. **Generative Adversarial Networks (GANs)**
#    - Use two neural networks (generator and discriminator) in competition
#    - Applied in image generation and style transfer
#
# 4. **Variational Autoencoders (VAEs)**
#    - Encode data into compressed representations and decode to generate new samples
#
# ## Key Applications
#
# ### Content Creation
# - **Writing**: Articles, marketing copy, code documentation
# - **Visual Arts**: Digital artwork, design prototypes, photo editing
# - **Music & Audio**: Composition, voice synthesis, sound effects
# - **Video**: Editing, animation, deepfakes
#
# ### Business & Enterprise
# - Customer service chatbots
# - Code generation and debugging
# - Data augmentation for training datasets
# - Drug discovery and molecular design
# - Product design and prototyping
#
# ### Research & Development
# - Scientific paper summarization
# - Hypothesis generation
# - Simulation and modeling
# - Protein folding predictions
#
# ## Major Players and Platforms
#
# ### Leading Organizations
# - **OpenAI**: GPT-4, DALL-E, ChatGPT
# - **Google/Alphabet**: Gemini, Bard, ImageGen
# - **Anthropic**: Claude family of models
# - **Meta**: LLaMA models
# - **Microsoft**: Copilot integration across products
# - **Stability AI**: Stable Diffusion
#
# ## Technical Architecture
#
# ### Training Process
# 1. **Pre-training**: Models learn from massive datasets (billions of parameters)
# 2. **Fine-tuning**: Adaptation for specific tasks or domains
# 3. **Reinforcement Learning from Human Feedback (RLHF)**: Alignment with human preferences
#
# ### Key Capabilities
# - Natural language understanding and generation
# - Context retention across long conversations
# - Multi-modal processing (text, image, audio combined)
# - Few-shot and zero-shot learning
#
# ## Benefits and Advantages
#
# - **Productivity Enhancement**: Automates routine creative and analytical tasks
# - **Accessibility**: Democratizes content creation for non-experts
# - **Personalization**: Tailored content and experiences at scale
# - **Innovation Acceleration**: Rapid prototyping and ideation
# - **Cost Reduction**: Lower production costs for various content types
#
# ## Challenges and Concerns
#
# ### Technical Limitations
# - **Hallucinations**: Generation of false or nonsensical information
# - **Bias**: Reflection of biases present in training data
# - **Computational Costs**: Significant energy and resource requirements
# - **Consistency**: Difficulty maintaining logical coherence in complex tasks
#
# ### Ethical and Social Issues
# - **Misinformation**: Potential for creating convincing fake content
# - **Copyright and IP**: Questions about ownership of AI-generated content
# - **Job Displacement**: Concerns about impact on creative professions
# - **Privacy**: Use of personal data in training sets
# - **Deepfakes**: Malicious use for fraud or harassment
# - **Environmental Impact**: High energy consumption for training and inference
#
# ## Regulatory Landscape
#
# ### Emerging Frameworks
# - **EU AI Act**: Risk-based classification of AI systems
# - **U.S. Executive Order on AI**: Safety, security, and transparency requirements
# - **China's Generative AI Regulations**: Content regulation and registration requirements
#
# ### Key Regulatory Concerns
# - Transparency and disclosure requirements
# - Safety testing and evaluation standards
# - Data privacy and protection
# - Intellectual property rights
# - Liability frameworks
#
# ## Market and Economic Impact
#
# ### Market Size
# - Global generative AI market projected to reach $110+ billion by 2030
# - Compound annual growth rate (CAGR) of 35-40% expected through the decade
#
# ### Investment Trends
# - Significant venture capital and corporate investment
# - Strategic acquisitions of AI startups
# - Infrastructure development (specialized chips, cloud services)
#
# ## Future Directions
#
# ### Emerging Trends
# - **Multimodal AI**: Seamless integration across text, image, video, and audio
# - **Agentic AI**: Systems capable of autonomous goal-directed behavior
# - **Smaller, More Efficient Models**: Optimization for edge devices and reduced costs
# - **Customization**: Industry and domain-specific fine-tuned models
# - **AI Safety**: Improved alignment and controllability mechanisms
#
# ### Research Frontiers
# - Reducing hallucinations and improving factuality
# - Better reasoning and logical capabilities
# - Enhanced interpretability and explainability
# - Energy-efficient architectures
# - Constitutional AI and value alignment
#
# ## Best Practices for Implementation
#
# 1. **Define Clear Use Cases**: Identify specific problems to solve
# 2. **Data Quality**: Ensure clean, representative training data
# 3. **Human Oversight**: Maintain human review for critical applications
# 4. **Ethical Guidelines**: Establish responsible AI principles
# 5. **Continuous Monitoring**: Track performance and potential issues
# 6. **Transparency**: Disclose AI-generated content when appropriate
#
# ## Conclusion
#
# Generative AI represents a transformative technology with vast potential across industries. While offering unprecedented capabilities for content creation and problem-solving, it requires careful consideration of ethical, social, and technical challenges. Success depends on balanced development that maximizes benefits while mitigating risks through responsible deployment, appropriate regulation, and ongoing research.
#
# ---
#
# **Note**: This overview synthesizes widely reported information about generative AI. For specific technical implementations or recent developments, consulting primary research papers, company documentation, and current industry reports is recommended.
# ✂️ SUMMARY AGENT distilling the research
#
# # Generative AI Research Summary
#
# ## Core Definition
# Generative AI systems create novel content (text, images, audio, video, code) by learning patterns from training data, distinguishing them from traditional AI that only analyzes existing information.
#
# ## Key Technologies
# - **Large Language Models (LLMs)**: Transformer-based text processors (GPT, Claude, LLaMA)
# - **Diffusion Models**: Image generators through iterative denoising (DALL-E, Stable Diffusion)
# - **GANs & VAEs**: Neural network architectures for content generation
#
# ## Primary Applications
# - Content creation (writing, visual arts, music, video)
# - Business solutions (chatbots, code generation, product design)
# - Scientific research (drug discovery, simulations, protein folding)
#
# ## Major Industry Players
# OpenAI, Google/Alphabet, Anthropic, Meta, Microsoft, and Stability AI lead development with products like GPT-4, Gemini, and Claude.
#
# ## Critical Benefits
# Productivity enhancement, democratized content creation, personalization at scale, innovation acceleration, and cost reduction.
#
# ## Key Challenges
#
# **Technical**: Hallucinations, bias, high computational costs, consistency issues
#
# **Ethical/Social**: Misinformation risks, copyright concerns, job displacement, privacy violations, deepfakes, environmental impact
#
# ## Regulatory Environment
# Emerging frameworks include the EU AI Act, U.S. Executive Orders, and China's regulations focusing on transparency, safety standards, and data protection.
#
# ## Market Outlook
# Projected to exceed $110 billion by 2030 with 35-40% annual growth, driven by substantial venture capital investment and infrastructure development.
#
# ## Future Trajectory
# Evolution toward multimodal integration, autonomous agentic systems, smaller efficient models, enhanced safety mechanisms, and improved factuality with reduced hallucinations.
#
# ## Implementation Recommendations
# Define clear use cases, ensure data quality, maintain human oversight, establish ethical guidelines, implement continuous monitoring, and practice transparency in disclosure.
#
# **Conclusion**: Generative AI offers transformative potential requiring balanced development through responsible deployment, appropriate regulation, and ongoing research to maximize benefits while mitigating significant technical and ethical risks.# Generative AI Research Summary
#
# ## Core Definition
# Generative AI systems create novel content (text, images, audio, video, code) by learning patterns from training data, distinguishing them from traditional AI that only analyzes existing information.
#
# ## Key Technologies
# - **Large Language Models (LLMs)**: Transformer-based text processors (GPT, Claude, LLaMA)
# - **Diffusion Models**: Image generators through iterative denoising (DALL-E, Stable Diffusion)
# - **GANs & VAEs**: Neural network architectures for content generation
#
# ## Primary Applications
# - Content creation (writing, visual arts, music, video)
# - Business solutions (chatbots, code generation, product design)
# - Scientific research (drug discovery, simulations, protein folding)
#
# ## Major Industry Players
# OpenAI, Google/Alphabet, Anthropic, Meta, Microsoft, and Stability AI lead development with products like GPT-4, Gemini, and Claude.
#
# ## Critical Benefits
# Productivity enhancement, democratized content creation, personalization at scale, innovation acceleration, and cost reduction.
#
# ## Key Challenges
#
# **Technical**: Hallucinations, bias, high computational costs, consistency issues
#
# **Ethical/Social**: Misinformation risks, copyright concerns, job displacement, privacy violations, deepfakes, environmental impact
#
# ## Regulatory Environment
# Emerging frameworks include the EU AI Act, U.S. Executive Orders, and China's regulations focusing on transparency, safety standards, and data protection.
#
# ## Market Outlook
# Projected to exceed $110 billion by 2030 with 35-40% annual growth, driven by substantial venture capital investment and infrastructure development.
#
# ## Future Trajectory
# Evolution toward multimodal integration, autonomous agentic systems, smaller efficient models, enhanced safety mechanisms, and improved factuality with reduced hallucinations.
#
# ## Implementation Recommendations
# Define clear use cases, ensure data quality, maintain human oversight, establish ethical guidelines, implement continuous monitoring, and practice transparency in disclosure.
#
# **Conclusion**: Generative AI offers transformative potential requiring balanced development through responsible deployment, appropriate regulation, and ongoing research to maximize benefits while mitigating significant technical and ethical risks.

# %% [markdown]
# ## Congrats!
#
# You've learned how to use agents as tools in Strands Agents to create more complex agentic applications

# %% [markdown]
# ---# Part 2: From Manual Instrumentation to Auto-Observability## The Problem: Manual Tracing Doesn't ScaleLook at what we just did above. Every single tool-agent required **~50 lines of boilerplate** just to emit basic spans. Let's quantify it:

# %%
# Let's count the observability tax in our code above

# Each tool function has ~20 lines of emit_span() calls
# For 3 tools + orchestrator calls, that's:
manual_lines_per_tool = 20  # emit_span wrappers, try/except, span_id generation
num_tools = 3
orchestrator_overhead = 10  # start/end spans around each orchestrator call

total_manual_lines = (manual_lines_per_tool * num_tools) + orchestrator_overhead
agent_logic_lines = 5 * num_tools  # actual agent creation + invocation per tool

print("=" * 60)
print("OBSERVABILITY TAX ANALYSIS")
print("=" * 60)
print(f"")
print(f"Manual tracing lines per tool:     {manual_lines_per_tool}")
print(f"Number of tools:                   {num_tools}")
print(f"Orchestrator overhead lines:       {orchestrator_overhead}")
print(f"")
print(f"Total manual observability code:   {total_manual_lines} lines")
print(f"Total actual agent logic:          {agent_logic_lines} lines")
print(f"")
print(f"Ratio: {total_manual_lines/agent_logic_lines:.1f}x more observability code than agent code!")
print(f"")
print("Problems with this approach:")
print("  1. Fragile: forget one emit_span() and you lose visibility")
print("  2. No session awareness: spans are flat, no execution lineage")
print("  3. No anomaly detection: all spans show 'success' even on silent failures")
print("  4. Scales linearly: 10 tools = 200+ lines of boilerplate")
print("  5. No context tracking: can't see what information flows between agents")
print("=" * 60)
# Out:
# ============================================================
# OBSERVABILITY TAX ANALYSIS
# ============================================================
#
# Manual tracing lines per tool:     20
# Number of tools:                   3
# Orchestrator overhead lines:       10
#
# Total manual observability code:   70 lines
# Total actual agent logic:          15 lines
#
# Ratio: 4.7x more observability code than agent code!
#
# Problems with this approach:
#   1. Fragile: forget one emit_span() and you lose visibility
#   2. No session awareness: spans are flat, no execution lineage
#   3. No anomaly detection: all spans show 'success' even on silent failures
#   4. Scales linearly: 10 tools = 200+ lines of boilerplate
#   5. No context tracking: can't see what information flows between agents
# ============================================================

# %% [markdown]
# ## Solution: LexiLensAI Auto-InstrumentationWhat if you could get full session-native observability with **one line of code**?Below is the `lexilens` SDK — it monkey-patches the Strands Agent class to automatically emit OpenTelemetry-compatible spans for every agent invocation, tool call, and delegation. Zero changes to your agent code.

# %%
# lexilens/sdk.py - Session-native auto-instrumentation for AI agents
# This is a working stub of the LexiLensAI SDK

import json
import uuid
import time
import functools
from datetime import datetime, timezone
from pathlib import Path
from dataclasses import dataclass, field, asdict
from typing import Optional, Dict, List, Any
from collections import defaultdict


@dataclass
class Span:
    trace_id: str
    span_id: str
    parent_span_id: Optional[str]
    session_id: str
    agent_name: str
    event: str
    status: str = "success"
    start_time: Optional[str] = None
    end_time: Optional[str] = None
    duration_ms: Optional[float] = None
    token_input: Optional[int] = None
    token_output: Optional[int] = None
    metadata: Dict = field(default_factory=dict)


class SessionTracker:
    """Tracks execution at the SESSION level, not just span level."""
    
    def __init__(self, session_id: str):
        self.session_id = session_id
        self.spans: List[Span] = []
        self.delegation_chain: List[str] = []
        self.total_tokens_in = 0
        self.total_tokens_out = 0
        self.tool_call_counts: Dict[str, int] = defaultdict(int)
        self.retry_tracker: Dict[str, List[float]] = defaultdict(list)
        self.anomalies: List[Dict] = []
    
    def add_span(self, span: Span):
        self.spans.append(span)
        if span.token_input:
            self.total_tokens_in += span.token_input
        if span.token_output:
            self.total_tokens_out += span.token_output
        
        # Track tool calls for retry detection
        tool_key = f"{span.agent_name}:{span.metadata.get('input', '')[:50]}"
        self.tool_call_counts[span.agent_name] += 1
        self.retry_tracker[tool_key].append(time.time())
        
        # Anomaly detection: retry storm (same agent + same input 3x in 60s)
        self._check_retry_storm(tool_key)
        
        # Anomaly detection: token explosion
        self._check_token_explosion(span)
    
    def _check_retry_storm(self, tool_key: str):
        calls = self.retry_tracker[tool_key]
        if len(calls) >= 3:
            recent = [t for t in calls if time.time() - t < 60]
            if len(recent) >= 3:
                self.anomalies.append({
                    "type": "retry_storm",
                    "severity": "high",
                    "agent": tool_key.split(":")[0],
                    "detail": f"Agent called {len(recent)}x in <60s with similar input",
                    "timestamp": datetime.now(timezone.utc).isoformat()
                })
    
    def _check_token_explosion(self, span: Span):
        if span.token_output and span.token_output > 4000:
            self.anomalies.append({
                "type": "token_explosion",
                "severity": "medium",
                "agent": span.agent_name,
                "detail": f"Single response used {span.token_output} output tokens",
                "timestamp": datetime.now(timezone.utc).isoformat()
            })
    
    def get_delegation_graph(self) -> Dict[str, List[str]]:
        """Returns adjacency list of agent delegations."""
        graph = defaultdict(set)
        span_map = {s.span_id: s for s in self.spans}
        for span in self.spans:
            if span.parent_span_id and span.parent_span_id in span_map:
                parent = span_map[span.parent_span_id]
                if parent.agent_name != span.agent_name:
                    graph[parent.agent_name].add(span.agent_name)
        return {k: list(v) for k, v in graph.items()}
    
    def summary(self) -> Dict:
        return {
            "session_id": self.session_id,
            "total_spans": len(self.spans),
            "total_tokens": {"input": self.total_tokens_in, "output": self.total_tokens_out},
            "unique_agents": list(set(s.agent_name for s in self.spans)),
            "delegation_graph": self.get_delegation_graph(),
            "anomalies": self.anomalies,
            "duration_ms": self._session_duration()
        }
    
    def _session_duration(self) -> Optional[float]:
        if len(self.spans) < 2:
            return None
        first = self.spans[0].start_time
        last = self.spans[-1].end_time or self.spans[-1].start_time
        if first and last:
            t1 = datetime.fromisoformat(first)
            t2 = datetime.fromisoformat(last)
            return (t2 - t1).total_seconds() * 1000
        return None


def _extract_agent_name(agent_self) -> str:
    """Extract a meaningful name from a Strands Agent instance."""
    # 1. Check for explicit name attribute
    name = getattr(agent_self, 'name', None)
    if name and name not in ("Agent", "Strands Agents"):
        return name
    
    # 2. Use system prompt to derive a descriptive name
    prompt = getattr(agent_self, 'system_prompt', None)
    if prompt:
        prompt_clean = prompt.strip()
        # Extract role from common patterns like "You are a specialized X assistant"
        lower = prompt_clean.lower()
        # Check orchestrator FIRST (its routing prompt mentions specialist keywords)
        if "route" in lower or "orchestrat" in lower or "specialized agents" in lower:
            return "orchestrator"
        elif "research" in lower:
            return "research_agent"
        elif "product" in lower or "recommendation" in lower:
            return "product_recommendation_agent"
        elif "travel" in lower or "trip" in lower or "itinerar" in lower:
            return "trip_planning_agent"
        elif "summar" in lower:
            return "summary_agent"
        else:
            # Use first 40 chars of prompt as name, cleaned up
            snippet = prompt_clean[:40].replace("\n", " ").strip()
            return snippet.replace(" ", "_")[:30]
    
    return "unnamed_agent"


def _extract_tokens_from_response(response) -> tuple:
    """Extract token counts from Strands Agent response object."""
    token_in = None
    token_out = None
    
    # Method 1: response.message.metadata.usage (Strands pattern)
    try:
        msg = getattr(response, 'message', None)
        if msg and isinstance(msg, dict):
            metadata = msg.get('metadata', {})
            usage = metadata.get('usage', {})
            token_in = usage.get('inputTokens') or usage.get('input_tokens')
            token_out = usage.get('outputTokens') or usage.get('output_tokens')
            if token_in:
                return (token_in, token_out)
    except (AttributeError, TypeError, KeyError):
        pass
    
    # Method 2: response.metrics
    try:
        metrics = getattr(response, 'metrics', None)
        if metrics:
            token_in = getattr(metrics, 'inputTokens', None) or getattr(metrics, 'input_tokens', None)
            token_out = getattr(metrics, 'outputTokens', None) or getattr(metrics, 'output_tokens', None)
            if token_in:
                return (token_in, token_out)
    except (AttributeError, TypeError):
        pass
    
    # Method 3: response.usage dict
    try:
        usage = getattr(response, 'usage', None)
        if usage and isinstance(usage, dict):
            token_in = usage.get('inputTokens') or usage.get('input_tokens')
            token_out = usage.get('outputTokens') or usage.get('output_tokens')
            if token_in:
                return (token_in, token_out)
    except (AttributeError, TypeError):
        pass
    
    return (token_in, token_out)


class LexiLens:
    """
    LexiLensAI Auto-Instrumentation SDK.
    
    Usage:
        lexilens = LexiLens.init(service_name="my-agent-app")
        # That's it. All Strands Agent calls are now traced.
    """
    
    _instance = None
    
    def __init__(self, service_name: str, output_dir: Optional[str] = None):
        self.service_name = service_name
        self.trace_id = str(uuid.uuid4())
        self.session_id = str(uuid.uuid4())
        self.output_dir = Path(output_dir) if output_dir else Path("./lexilens_traces")
        self.output_dir.mkdir(parents=True, exist_ok=True)
        self.trace_file = self.output_dir / f"session_{self.session_id[:8]}.jsonl"
        self.session = SessionTracker(self.session_id)
        self._span_stack: List[str] = []
        self._original_agent_call = None
        self._patched = False
    
    @classmethod
    def init(cls, service_name: str = "strands-app", output_dir: Optional[str] = None) -> 'LexiLens':
        """Initialize LexiLensAI. Patches Strands Agent automatically."""
        instance = cls(service_name=service_name, output_dir=output_dir)
        instance._patch_strands()
        cls._instance = instance
        print(f"[LexiLens] Initialized for '{service_name}'")
        print(f"[LexiLens] Session: {instance.session_id[:8]}...")
        print(f"[LexiLens] Traces -> {instance.trace_file}")
        return instance
    
    def _patch_strands(self):
        """Monkey-patch strands.Agent.__call__ to auto-emit spans."""
        if self._patched:
            return
        
        from strands import Agent as StrandsAgent
        original_call = StrandsAgent.__call__
        lexilens_ref = self
        
        @functools.wraps(original_call)
        def instrumented_call(agent_self, *args, **kwargs):
            agent_name = _extract_agent_name(agent_self)
            
            # Determine parent from call stack
            parent_span_id = lexilens_ref._span_stack[-1] if lexilens_ref._span_stack else None
            span_id = str(uuid.uuid4())
            
            # Push onto stack for child detection
            lexilens_ref._span_stack.append(span_id)
            
            start = datetime.now(timezone.utc)
            span = Span(
                trace_id=lexilens_ref.trace_id,
                span_id=span_id,
                parent_span_id=parent_span_id,
                session_id=lexilens_ref.session_id,
                agent_name=agent_name,
                event="agent_invocation",
                start_time=start.isoformat(),
                metadata={"input": str(args[0])[:200] if args else ""}
            )
            
            try:
                response = original_call(agent_self, *args, **kwargs)
                
                end = datetime.now(timezone.utc)
                span.end_time = end.isoformat()
                span.duration_ms = (end - start).total_seconds() * 1000
                span.status = "success"
                
                # Extract token usage from Strands response
                token_in, token_out = _extract_tokens_from_response(response)
                span.token_input = token_in
                span.token_output = token_out
                
                span.metadata["output_size"] = len(str(response))
                
                return response
                
            except Exception as e:
                end = datetime.now(timezone.utc)
                span.end_time = end.isoformat()
                span.duration_ms = (end - start).total_seconds() * 1000
                span.status = "error"
                span.metadata["error"] = str(e)
                raise
                
            finally:
                # Record span
                lexilens_ref.session.add_span(span)
                lexilens_ref._write_span(span)
                lexilens_ref._span_stack.pop()
        
        StrandsAgent.__call__ = instrumented_call
        self._original_agent_call = original_call
        self._patched = True
    
    def _write_span(self, span: Span):
        with open(self.trace_file, "a") as f:
            f.write(json.dumps(asdict(span)) + "\n")
    
    def report(self):
        """Print session summary with anomaly detection results."""
        s = self.session.summary()
        print("\n" + "=" * 60)
        print("LEXILENS SESSION REPORT")
        print("=" * 60)
        print(f"Session:        {s['session_id'][:8]}...")
        print(f"Total spans:    {s['total_spans']}")
        print(f"Tokens:         {s['total_tokens']['input'] or 0} in / {s['total_tokens']['output'] or 0} out")
        print(f"Agents used:    {', '.join(s['unique_agents'])}")
        if s['duration_ms']:
            print(f"Duration:       {s['duration_ms']:.0f}ms")
        else:
            print("Duration:       N/A")
        
        if s['delegation_graph']:
            print(f"\nDelegation Graph:")
            for parent, children in s['delegation_graph'].items():
                for child in children:
                    print(f"  {parent} -> {child}")
        
        if s['anomalies']:
            print(f"\n  ANOMALIES DETECTED: {len(s['anomalies'])}")
            for a in s['anomalies']:
                print(f"  [{a['severity'].upper()}] {a['type']}: {a['detail']}")
        else:
            print(f"\n  No anomalies detected")
        
        print("=" * 60)
        return s
    
    def unpatch(self):
        """Restore original Strands Agent behavior."""
        if self._original_agent_call and self._patched:
            from strands import Agent as StrandsAgent
            StrandsAgent.__call__ = self._original_agent_call
            self._patched = False
            print("[LexiLens] Unpatched - original Agent behavior restored")


print("LexiLens SDK loaded")
# Out:
# LexiLens SDK loaded

# %% [markdown]
# ## The "After": Same Agents, Zero Manual SpansNow let's run the **exact same orchestrator pattern** — but with LexiLensAI auto-instrumentation instead of manual `emit_span()` calls.Notice: **no changes to agent code.** One `init()` call does everything.

# %%
# Initialize LexiLensAI - this is the ONLY observability code you need
lexilens = LexiLens.init(
    service_name="strands-multi-agent-demo",
    output_dir="/Users/rbakshi/Downloads/agentic_ai/LexiLensAI/lexilens_runtime_engine/raw_traces/strands_auto"
)
# Out:
# [LexiLens] Initialized for 'strands-multi-agent-demo'
# [LexiLens] Session: d7b187f9...
# [LexiLens] Traces -> /Users/rbakshi/Downloads/agentic_ai/LexiLensAI/lexilens_runtime_engine/raw_traces/strands_auto/session_d7b187f9.jsonl

# %%
# LOOK: No emit_span() anywhere. Same agent logic, zero observability tax.

@tool
def research_assistant_v2(query: str) -> str:
    """Research specialist - provides factual, well-sourced information."""
    agent = Agent(
        model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
        system_prompt=RESEARCH_ASSISTANT_PROMPT,
    )
    response = agent(query)
    return str(response)


@tool  
def product_recommendation_v2(query: str) -> str:
    """Product recommendation specialist - personalized suggestions."""
    agent = Agent(
        model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
        system_prompt="You are a specialized product recommendation assistant. Provide personalized product suggestions.",
    )
    response = agent(query)
    return str(response)


@tool
def trip_planning_v2(query: str) -> str:
    """Travel planning specialist - detailed itineraries."""
    agent = Agent(
        model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
        system_prompt="You are a specialized travel planning assistant. Create detailed travel itineraries.",
    )
    response = agent(query)
    return str(response)


# Compare the line counts:
print("BEFORE (with manual emit_span):")
print("  research_assistant:    65 lines")
print("  product_recommendation: 65 lines")  
print("  trip_planning:          65 lines")
print("  Total:                 195 lines\n")
print("AFTER (with LexiLensAI):")
print("  research_assistant_v2:  6 lines")
print("  product_recommendation_v2: 6 lines")
print("  trip_planning_v2:       6 lines")
print("  Total:                  18 lines")
print(f"\n  -> {195//18}x reduction in code, BETTER observability")
# Out:
# BEFORE (with manual emit_span):
#   research_assistant:    65 lines
#   product_recommendation: 65 lines
#   trip_planning:          65 lines
#   Total:                 195 lines
#
# AFTER (with LexiLensAI):
#   research_assistant_v2:  6 lines
#   product_recommendation_v2: 6 lines
#   trip_planning_v2:       6 lines
#   Total:                  18 lines
#
#   -> 10x reduction in code, BETTER observability

# %%
# Create orchestrator with clean tools
orchestrator_v2 = Agent(
    model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    system_prompt=MAIN_SYSTEM_PROMPT,
    tools=[research_assistant_v2, product_recommendation_v2, trip_planning_v2],
)

os.environ["BYPASS_TOOL_CONSENT"] = "true"

# Run a multi-agent query - LexiLens captures everything automatically
response = orchestrator_v2("Research Spain and plan me a 7-day trip with hotel recommendations")
# Out:
# Tool #1: research_assistant_v2
#
# Tool #2: trip_planning_v2
# # Spain Travel Guide
#
# ## Overview
# Spain is Western# 7-Day Spain Europe's second-largest country, known Itinerary: Barcelona for its diverse & regions, rich history, vib Madridrant culture, and Mediterranean
#
# ## Overview lifestyle
# This it.inerary combines Spain
#
# ## Main's two Attractions most vibrant cities,
#
# ### Major offering Cities
# - **Madrid**: art, architecture P, culturerado Museum, Royal Palace, Ret, and cuisine.iro Park,
#
# --- vib
#
# ## **Daysrant nightlife
# - **Barcelona**: 1-4 Sagrada Família: Barcelona**, Park Güell, Gothic
#
# ### ** Quarter, Las Ramblas
# - **AccommodationSeville**: Alcázar Palace:, Cathedral Barcelona with** Giralda tower
# **, flRecommendedamenco heart Hotelsland:**
# - **
# - **Granada**: Alhambra palaceLuxury complex:** Hotel, Al Artsbaicín neighborhood Barcelona (5★
# - **Valencia**: City of Arts and Sciences, beaches) - Be, paachfront,ella birth stunningplace
#
# ### UNESCO views World Heritage Sites
# Spain, € has 300-45049/night
# - **Mid-Range UNESCO:** Hotel Prakt sitesik, including  Rambla (4★) - CentralAlhambra, location, modern Sagrada Família,, historic €120 Toledo-180/night
# - **Budget,:** TO CamCino de Santiago pilgrimage routes, and Ga Hosteludi's works Barcelona.
#
# ## Best Regions to Visit (3
#
# -★) - Clean **Andalusia**: Moorish, social atmosphere, €60 architecture, white villages, flamenco-90/night
#
# ---
# - **Catalonia**: Barcelona
#
# ### **Day 1:, Costa Arrival & Gothic Brava beaches Quarter**
# -, **Morning:** Arrive in Py Barcelona, check into hotel,renees mountains
# - **Bas fresque Country**: Sanhen up
# - **Afternoon:**  Sebastián, cul
#   - Explore Gothic Quarter (inary excellence,Barri Gò uniquetic) culture
# - **Balearic
#   - Visit Islands**: Mallorca, Ib Barcelona Cathedraliza, Menorca (
#   - Wbeachesander Las and Ramblas
# - **Evening night:** life)
# - **Gal
#   - Dinner at Elicia**: Green landscapes Xampanyet (tap, Santiagoas in de Compostela, seaf Elood Born)
# - **
#   - Stroll through ElCanary Islands**: Year Born neighborhood
#
# ###-round warm **Day 2: weather, volcanic G landscapesaudí's
#
# ## Spanish Masterpi Cultureeces**
# - **Morning:**
#   - Sag
#
# ### Lifestylerada Família
# - **Si (bookesta tradition tickets in**: Many advance, shops  close 2-59 PM ( lessAM entry common)
#   - Allow in big 2-3 hours cities)
# - **Late
# - **Afternoon:** dining
#   - Park Güell**: Lunch (pre -book t2imed entry)
#   - Lunch-4 PM, dinner 9 in-11 PM
# - **Social Grà culturecia neighborhood
# - **Evening:** **: Outdoor
#   - Pas terrseig deaces, pas Gràcia: Casa Batlló & Casa Milà (exterior viewing)
#   - Dinner at Cervecería Catalana
#
# ### **Day 3: Montjuïc & Beach**
# - **Morning:**
#   - Montjuïc Castle (cable car ride up)
#   - Magic Fountain area
#   eos (evening st-rolls)
#
# ### Festivals
# - La MN Tomatina (August, BuAC (ñol)
# - Running of the Bulls (JulyNational, Pamplona)
# - Las Fallas (March, Valencia)
# - Semana Santa (Holy Week proc Artessions)
# - Feria de Abril (April, Seville)
#
# ## Food & Cuisine
#
# ### Must-Try Dishes
# - **Tap Museumas**: Small plates (pat of Catalonia)
# - **atas bravas, cAfternoon:**
#   -roquetas, jam Barcelón iboneta Beach -érico)
# - **Pa relella**: Rice dish fromax and Valencia ( lunchseaf atood or mixed a) chir
# - **Gazpacho**:inguito ( Cold tomato soup
# - **beach bar)
# -Tortilla española**: **Evening:**
#   - Gothic Potato om Quarter tapelet
# - **Churas crawros conl
#   - Optional chocolate**: Breakfast: Fl/amenco show at Tablaosnack favorite Flamenco Cor
#
# ### Regionaldobes
#
# ### **Day 4 Specialties
# -: Day Bas Trip orque pint Marketsxos (Basque Country**
# **)
# - CocOptionhinillo asado (ro A -ast suckling pig, Montser Castrat Dayile Trip:**
# - Mountain)
# - Pul monasterypo a la gallega (Gal,ician oct spectacular views (opus)
# - Crfullema catalana (Cat day)alan dessert)
#
# ### Dining
#
# **Option B - City Tips Markets
# - T:**
# - **ipping:Morning:** La 5 Boqueria Market-10% if satisfied
# - **Afternoon:** Pic;asso Museum, not oblig lunchatory
# - Menu in del día: El Born Affordable
# - **Evening:** Sunset fixed at Bun lunchkers del me Carmel,nus (€ fare10well dinner
#
# **-15Late) Evening
#
# ## Weather & Best Time:** Take to Visit
#
# ### Climate AVE high Zones
# - **Mediterranean-speed train to Madrid (3 coast **: Hot, dry summers;hours)
#
# ---
#
# ## **Days mild winters
# - **Interior 5-7: Madrid** (
#
# ### **Accommodation: Madrid**Madrid
# **Recommended Hotels:**
# - **)Luxury:** Hotel Único**: Hot Madrid summers (5★) - Bout, coldique luxury, €280 winters-400
# - **North (/night
# - **Mid-Range:** Hotel LiGalabicia,eny Bas (4★) - Nearque)**: Ra Graniny, Vía, €100 temp-160erate year/night
# - **Budget:** The-round
# - **South ( HatAndalusia) Madrid (3★) - Tren**: Verydy hos hot summerstel, €55 (-8540/night
#
# ---
#
# ### **Day° 5: Art & Royal MadridC+), mild winters
#
# ### Best Times
# - **Spring (April**
# - **Morning:** -June
#   - Arrive)**: Ideal from weather Barcelona,, festivals check in,
#   - P fewer crowds
# - **Fallrado Museum (book ahead (September-October)**: Warm, temperatures 10, harvest AM entry season)
# - **Afternoon:**
# - **Summer (July-August
#   -)**: Peak Retiro Park - season, very row hot, crowboatded, higher on prices
# - **Winter**: the Good lake
#   - Crystal for cities Palace, skiing
#   ;- Lunch near some park coastal
# - **Evening:**
#    areas quiet- Royal
#
# ## Palace exterior Practical Travel Tips
#
# ### Transportation
# - & **High Alm-speed trainsudena Cathedral
#   - Dinner ( at MercAVE)**: Connectado de San Miguel
#
# ### **Day major cities efficiently 6: Museums
# - **Budget & Neighborhoods airlines**
# - **Morning:** **: Ryanair, Vu
#   - Reeling forina domestic flights
# - **Metro Sofía Museum ( systems**: Madrid, Barcelona haveGuer excellent networksnica &
# - **Car modern art)
# - **Afternoon:**
#   - rental**: Useful Gran for rural Vía shopping areas, villages
#   - Mal
#
# ### Languageasaña neighborhood (
# - Official language: Spanish (Castellhipano)
# - Regionalster caf languages: Catés)
#   alan, Bas- Lunch atque, Galician
# - English a spoken local in tourist areas; tav learningern
# - **Evening:**  basic Spanish helpful
#
# ### Money
#   - Chueca neighborhood
#   - Dinner
# - Currency: Euro (€) at Tab
# - ATMs widely available
# - Crediterna La cards accepted in most places B
# - Cashola ( stilltraditional preferred in small coc barsido madrileño),
#   - Ro marketsoftop drinks
#
# ### Safety at
# - Generally Cír veryculo de safe for travelers Bellas Artes
#
# ###
# - Watch **Day 7: Final for pickpockets in Barcelona Day, & Madrid tourist Departure**
# ** areas
# - EmergencyOption number A - Toledo: 112
#
# ### Day Trip** Accommodation
# - Range (if early from budget hostels ( flight€15-30 next) day):
# - UNESCO to luxury hotels World Heritage medieval
# - Par city (adores1:  Historichour by state train)-run hotels in
#
# **Option B - Relax casted Madrid Morningles,:**
# - ** monastMorning:** eries
# - Air
#   - Thybnb popularssen-Bornemisza Museum in ( citiescompleting "
# - BookGolden ahead Triangle for peak")
#    season (- Chursummerros con chocolate at San, major festivals)
#
# ### Ginés
# - **Afternoon Entry:**
#   - Last Requirements
# - EU-minute shopping on citizens: ID Gran Vía
#   - Plaza card sufficient Mayor &
# - Many Pu countries:erta del Sol
# - **Evening:** Visa- Departurefree for 90 days ( or overnightSchengen) for
# - Check next current day
#
# ---
#
# ## **Budget requirements based Estimate ( on nationality
#
# ### CulturalPer Person)** Etiquette
# - Greet
#
# | with two Category kisses ( | Budgetcheek- | Midto-cheek)
# --Range | Luxury |
# | Dress moder----------|---------|-----------|---------|ately when visiting churches
# | Hotels
# - ( Loud7 nights) | €420 conversation is-630 normal | €770 and-1,190 not | €2 considered,030 rude
# - Restaurants-2,975 don |
# | Meals |'t rush €210 you-280 | €350; ask-490 | €560 for "-700 |
# | Attractionsla | €150-200 | € cuenta"150 (bill-200)
#
# ** | €150Budget-200 |
# | Transport estimate | €100**: €50-80/day budget-150 | €100-150 travel | €200; €100-150/day mid-300 |
# | **-range; €200+Total** | **€880/day luxury
#
# Spain-1,260 offers incredible diversity—** | **€1,370from beaches-2 to mountains, modern,030 cities to medieval** | **€2 towns, making,940 it suitable-4 for all,175 travel** |
#
# ---
#
# ## **Essential styles. Tips**
#
# **Transportation:**
# - Barcelona: T-10 metro card (10 rides)
# - Madrid: Tourist Travel Pass (unlimited rides)
# - Barcelona-Madrid: AVE train (~€50-100)
#
# **Dining:**
# - Lunch is 2-4 PM, dinner after 9 PM
# - Menu del día (lunch special) = great value
# - Tipping: 5-10% optional
#
# **Reservations Required:**
# - Sagrada Família
# - Park Güell
# - Prado Museum
# - Any flamenco shows
#
# **Best Times:**
# - Visit museums at opening to avoid crowds
# - Book attractions online in advance
#
# Enjoy your Spanish adventure! 🇪🇸Perfect! I've researched Spain and created a comprehensive 7-day itinerary for you. Here's what you need to know:
#
# ## 🇪🇸 **Your 7-Day Spain Adventure**
#
# ### **Trip Overview**
# Your itinerary covers Spain's two most iconic cities: **Barcelona** (4 days) and **Madrid** (3 days), connected by high-speed train.
#
# ---
#
# ## **📍 BARCELONA (Days 1-4)**
#
# ### **Hotel Recommendations:**
# - **💎 Luxury:** Hotel Arts Barcelona (5★) - €300-450/night - Beachfront location
# - **🏨 Mid-Range:** Hotel Praktik Rambla (4★) - €120-180/night - Central & modern
# - **💰 Budget:** TOC Hostel Barcelona - €60-90/night - Social & clean
#
# ### **Highlights:**
# - ✨ **Gaudí's Masterpieces:** Sagrada Família, Park Güell, Casa Batlló
# - 🏛️ **Gothic Quarter:** Medieval streets, Barcelona Cathedral, Las Ramblas
# - 🏖️ **Barceloneta Beach:** Relax by the Mediterranean
# - 🏔️ **Montjuïc:** Castle, museums, and panoramic views
# - 🍽️ **Food Scene:** Tapas crawls, La Boqueria Market
#
# ---
#
# ## **📍 MADRID (Days 5-7)**
#
# ### **Hotel Recommendations:**
# - **💎 Luxury:** Hotel Único Madrid (5★) - €280-400/night - Boutique elegance
# - **🏨 Mid-Range:** Hotel Liabeny (4★) - €100-160/night - Near Gran Vía
# - **💰 Budget:** The Hat Madrid - €55-85/night - Trendy hostel
#
# ### **Highlights:**
# - 🎨 **Art Golden Triangle:** Prado, Reina Sofía, Thyssen museums
# - 👑 **Royal Palace & Gardens:** Spectacular architecture
# - 🌳 **Retiro Park:** Rowboats, Crystal Palace, gardens
# - 🛍️ **Gran Vía:** Shopping and entertainment hub
# - 🍫 **Churros con Chocolate:** At the famous San Ginés café
#
# ---
#
# ## **💰 Budget Estimates (7 nights, per person):**
#
# - **Budget:** €880-1,260
# - **Mid-Range:** €1,370-2,030
# - **Luxury:** €2,940-4,175
#
# ---
#
# ## **⚡ Essential Tips:**
#
# 1. **Book in Advance:** Sagrada Família, Park Güell, and Prado Museum tickets
# 2. **Transportation:** Barcelona-Madrid AVE train (3 hours, €50-100)
# 3. **Meal Times:** Lunch 2-4 PM, Dinner after 9 PM
# 4. **Best Time:** Spring (April-June) or Fall (September-October)
# 5. **Language:** Basic Spanish phrases helpful, English spoken in tourist areas
#
# The itinerary balances iconic attractions, local culture, amazing food, and relaxation time. Both cities have excellent public transportation, making it easy to get around!
#
# Would you like me to adjust anything about the itinerary, such as focusing on different cities, extending your stay, or adding specific activities?

# %%
# One call to see the full session picture
session_data = lexilens.report()
# Out:
# ============================================================
# LEXILENS SESSION REPORT
# ============================================================
# Session:        d7b187f9...
# Total spans:    3
# Tokens:         3788 in / 3478 out
# Agents used:    trip_planning_agent, orchestrator, research_agent
# Duration:       34777ms
#
# Delegation Graph:
#   trip_planning_agent -> research_agent
#   orchestrator -> trip_planning_agent
#
#   No anomalies detected
# ============================================================

# %% [markdown]
# ## Session Graph VisualizationLexiLensAI reconstructs the execution as a **directed session graph** — showing exactly which agent delegated to which, the token cost at each node, and where anomalies occurred.

# %%
# Install matplotlib into notebook venv and import it
import subprocess, sys
subprocess.check_call([sys.executable, "-m", "pip", "install", "matplotlib", "-q"],
                      stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
print(f"matplotlib {matplotlib.__version__} loaded from {matplotlib.__file__}")
# Out:
# matplotlib 3.11.1 loaded from /Users/rbakshi/Downloads/agentic_ai/samples/python/01-learn/10-agents-as-tools/.venv/lib/python3.12/site-packages/matplotlib/__init__.py

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from collections import defaultdict

def visualize_session_graph(session, title="Agent Session Graph"):
    """
    Renders the session delegation graph using matplotlib.
    Nodes = agents, Edges = delegations, Node size = token usage.
    """
    
    spans = session.spans
    if not spans:
        print("No spans recorded yet.")
        return
    
    # Build graph data
    nodes = {}
    edges = []
    
    span_map = {s.span_id: s for s in spans}
    
    for span in spans:
        name = span.agent_name
        if name not in nodes:
            nodes[name] = {"tokens_in": 0, "tokens_out": 0, "calls": 0, "has_anomaly": False}
        nodes[name]["tokens_in"] += span.token_input or 0
        nodes[name]["tokens_out"] += span.token_output or 0
        nodes[name]["calls"] += 1
        
        if span.parent_span_id and span.parent_span_id in span_map:
            parent_name = span_map[span.parent_span_id].agent_name
            edges.append((parent_name, name))
    
    # Check anomalies
    for anomaly in session.anomalies:
        agent = anomaly.get("agent", "")
        if agent in nodes:
            nodes[agent]["has_anomaly"] = True
    
    # Layout: simple hierarchical
    levels = defaultdict(list)
    all_targets = set(e[1] for e in edges)
    all_sources = set(e[0] for e in edges)
    roots = all_sources - all_targets
    
    if not roots:
        roots = {spans[0].agent_name}
    
    # BFS for levels
    visited = set()
    queue = [(r, 0) for r in roots]
    while queue:
        node, level = queue.pop(0)
        if node in visited:
            continue
        visited.add(node)
        levels[level].append(node)
        for src, tgt in edges:
            if src == node and tgt not in visited:
                queue.append((tgt, level + 1))
    
    # Add unvisited nodes
    for name in nodes:
        if name not in visited:
            max_level = max(levels.keys()) + 1 if levels else 0
            levels[max_level].append(name)
    
    # Calculate positions
    positions = {}
    for level, names in levels.items():
        for i, name in enumerate(names):
            x = (i + 0.5) * (10.0 / max(len(names), 1))
            y = -level * 2.5
            positions[name] = (x, y)
    
    # Draw
    fig, ax = plt.subplots(1, 1, figsize=(12, 8))
    ax.set_xlim(-1, 11)
    y_vals = [p[1] for p in positions.values()]
    ax.set_ylim(min(y_vals) - 2, max(y_vals) + 2)
    ax.axis('off')
    ax.set_title(title, fontsize=16, fontweight='bold', pad=20)
    
    # Draw edges
    drawn_edges = set()
    for src, tgt in edges:
        edge_key = (src, tgt)
        if edge_key in drawn_edges:
            continue
        drawn_edges.add(edge_key)
        
        if src in positions and tgt in positions:
            x1, y1 = positions[src]
            x2, y2 = positions[tgt]
            ax.annotate("",
                xy=(x2, y2), xytext=(x1, y1),
                arrowprops=dict(arrowstyle="->", color="#555555", lw=2))
    
    # Draw nodes
    for name, pos in positions.items():
        info = nodes.get(name, {"tokens_in": 0, "tokens_out": 0, "calls": 0, "has_anomaly": False})
        
        if info["has_anomaly"]:
            color = "#FF4444"
            edge_color = "#CC0000"
        elif name in roots:
            color = "#4A90D9"
            edge_color = "#2A5F8F"
        else:
            color = "#5CB85C"
            edge_color = "#3D8B3D"
        
        circle = plt.Circle(pos, 0.6, color=color, ec=edge_color, lw=2, zorder=5)
        ax.add_patch(circle)
        
        short_name = name[:20] if len(name) > 20 else name
        ax.text(pos[0], pos[1] + 0.05, short_name, ha='center', va='center',
                fontsize=8, fontweight='bold', color='white', zorder=6)
        
        token_str = f"{info['tokens_in']+info['tokens_out']} tok | {info['calls']}x"
        ax.text(pos[0], pos[1] - 0.9, token_str, ha='center', va='top',
                fontsize=7, color='#666666')
    
    # Legend
    legend_elements = [
        mpatches.Patch(color='#4A90D9', label='Orchestrator'),
        mpatches.Patch(color='#5CB85C', label='Specialist Agent'),
        mpatches.Patch(color='#FF4444', label='Anomaly Detected'),
    ]
    ax.legend(handles=legend_elements, loc='lower right', fontsize=9)
    
    plt.tight_layout()
    plt.savefig("session_graph.png", dpi=150, bbox_inches='tight')
    plt.show()
    print(f"\nGraph saved to session_graph.png")


# Render the session graph from our auto-instrumented run
visualize_session_graph(lexilens.session, title="Multi-Agent Session Graph - Auto-Instrumented by LexiLensAI")
# Out:
# Graph saved to session_graph.png

# %% [markdown]
# ## Anomaly Detection: Catching Silent FailuresTraditional tracing shows "success" for every span. But LexiLensAI detects **session-level anomalies** — problems that only become visible when you look at the execution as a whole.Let's simulate a retry storm (agent calling itself repeatedly with the same query):

# %%
# Simulate a retry storm - agent called 5x with same input in rapid succession
# In production, this happens when an agent isn't satisfied with its own output
# and re-queries. Each individual call "succeeds" but the session is burning tokens.

import time

print("Simulating retry storm...\n")

for i in range(5):
    fake_span = Span(
        trace_id=lexilens.trace_id,
        span_id=str(uuid.uuid4()),
        parent_span_id=lexilens._span_stack[-1] if lexilens._span_stack else None,
        session_id=lexilens.session_id,
        agent_name="research_agent_retry_sim",
        event="agent_invocation",
        status="success",  # Each call "succeeds"!
        start_time=datetime.now(timezone.utc).isoformat(),
        end_time=datetime.now(timezone.utc).isoformat(),
        duration_ms=1200 + (i * 300),
        token_input=500,
        token_output=2000,
        metadata={"query": "What are the best hotels in Barcelona?"}  # Same query each time
    )
    lexilens.session.add_span(fake_span)
    time.sleep(0.1)  # Rapid succession

# Now check what LexiLens caught
print("All 5 calls returned 'success'. Traditional tracing sees nothing wrong.")
print("But LexiLensAI detects:\n")

lexilens.report()
# Out:
# Simulating retry storm...
#
# All 5 calls returned 'success'. Traditional tracing sees nothing wrong.
# But LexiLensAI detects:
#
#
# ============================================================
# LEXILENS SESSION REPORT
# ============================================================
# Session:        d7b187f9...
# Total spans:    8
# Tokens:         6288 in / 13478 out
# Agents used:    trip_planning_agent, orchestrator, research_agent, research_agent_retry_sim
# Duration:       55702ms
#
# Delegation Graph:
#   trip_planning_agent -> research_agent
#   orchestrator -> trip_planning_agent
#
#   ANOMALIES DETECTED: 3
#   [HIGH] retry_storm: Agent called 3x in <60s with similar input
#   [HIGH] retry_storm: Agent called 4x in <60s with similar input
#   [HIGH] retry_storm: Agent called 5x in <60s with similar input
# ============================================================
# {'session_id': 'd7b187f9-e15a-4956-9b9d-9d661318f2a9',
#  'total_spans': 8,
#  'total_tokens': {'input': 6288, 'output': 13478},
#  'unique_agents': ['trip_planning_agent',
#   'orchestrator',
#   'research_agent',
#   'research_agent_retry_sim'],
#  'delegation_graph': {'trip_planning_agent': ['research_agent'],
#   'orchestrator': ['trip_planning_agent']},
#  'anomalies': [{'type': 'retry_storm',
#    'severity': 'high',
#    'agent': 'research_agent_retry_sim',
#    'detail': 'Agent called 3x in <60s with similar input',
#    'timestamp': '2026-07-19T19:27:45.328694+00:00'},
#   {'type': 'retry_storm',
#    'severity': 'high',
#    'agent': 'research_agent_retry_sim',
#    'detail': 'Agent called 4x in <60s with similar input',
#    'timestamp': '2026-07-19T19:27:45.434213+00:00'},
#   {'type': 'retry_storm',
#    'severity': 'high',
#    'agent': 'research_agent_retry_sim',
#    'detail': 'Agent called 5x in <60s with similar input',
#    'timestamp': '2026-07-19T19:27:45.538324+00:00'}],
#  'duration_ms': 55702.225}

# %% [markdown]
# ## Key Insight| Aspect | Manual emit_span() | LexiLensAI ||--------|-------------------|------------|| Code overhead | 50+ lines per tool | 1 line total || Session awareness | None (flat spans) | Full execution graph || Anomaly detection | None | Retry storms, token explosion, context drift || Delegation tracking | Manual parent_span_id | Automatic via call stack || Works across frameworks | Custom per framework | Strands, Claude SDK, LangChain |**The difference isn't just less code. It's a fundamentally different unit of analysis: the Session, not the Span.**---*Built by CurvSort | [github.com/cuvsort/agent-session-graph](https://github.com/cuvsort/agent-session-graph) | [curvsort.com/lexilensai](https://www.curvsort.com/lexilensai)*
