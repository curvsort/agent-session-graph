# %% [markdown]
# "Agents as Tools" is an architectural pattern in AI systems where specialized AI agents are wrapped as callable functions (tools) that can be used by other agents. This creates a hierarchical structure where:
#
# 1. A primary "orchestrator" agent handles user interaction and determines which specialized agent to call
#
# 2. Specialized "tool agents" perform domain-specific tasks when called by the orchestrator
#
# This approach mimics human team dynamics, where a manager coordinates specialists, each bringing unique expertise to solve complex problems. Rather than a single agent trying to handle everything, tasks are delegated to the most appropriate specialized agent.

# %% [markdown]
# ## Key Benefits and Core Principles

# %% [markdown]
# The "Agents as Tools" pattern offers several advantages:
#
# - Separation of concerns: Each agent has a focused area of responsibility, making the system easier to understand and maintain
# - Hierarchical delegation: The orchestrator decides which specialist to invoke, creating a clear chain of command
# - Modular architecture: Specialists can be added, removed, or modified independently without affecting the entire system
# - Improved performance: Each agent can have tailored system prompts and tools optimized for its specific task

# %%
import sys
print(sys.executable)
# Out:
# /Users/rbakshi/.pyenv/versions/3.12.2/bin/python3.12

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: strands-agents in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.41.0)
# Requirement already satisfied: strands-agents-tools in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.43.24)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.43.24)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.18.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.23.0)
# Requirement already satisfied: mcp<2.0.0,>=1.23.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.27.1)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.42.1)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.63b1)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.42.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.13.5)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: pillow<13.0.0,>=12.1.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (12.2.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.52)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.13.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.3.4)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.28.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.13.3)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.24.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.19.0,>=0.18.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (0.18.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.19.1)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.12.3)
# Requirement already satisfied: six<2,>=1.15 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: anyio>=4.5 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (4.13.0)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: httpx<1.0.0,>=0.27.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (2.14.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.0.29)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (3.4.4)
# Requirement already satisfied: starlette>=0.27 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.48.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.63b1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.63b1)
# Requirement already satisfied: wrapt<3.0.0,>=1.0.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.63b1->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.63b1)
# Requirement already satisfied: packaging>=18.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.63b1->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (24.1)
# Requirement already satisfied: wcwidth in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (2.46.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.18.0)
# Requirement already satisfied: slack_sdk<4,>=3.38.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.42.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.5)
# Requirement already satisfied: httpcore==1.* in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from httpx<1.0.0,>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: cryptography>=3.4.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (48.0.0)
# Requirement already satisfied: click>=7.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (8.4.1)
# Requirement already satisfied: cffi>=2.0.0 in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pycparser in /Users/rbakshi/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (2.22)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import strands
import boto3
import pydantic

print("All imports successful")
# Out:
# All imports successful

# %%
import os

from strands import Agent, tool
from strands_tools import file_write

# %% [markdown]
# ---
# # Part 1: Manual Instrumentation — The Observability Tax
#
# In this section we instrument a multi-agent orchestrator workflow **by hand** using custom `emit_span()` calls. This is what most teams do today when they need visibility into agent behavior.
#
# Pay attention to how much boilerplate this requires per tool.

# %%
import json
import uuid
from datetime import datetime
from pathlib import Path

TRACE_DIR = Path("./raw_traces/strands_manual")
TRACE_DIR.mkdir(parents=True, exist_ok=True)

TRACE_FILE = TRACE_DIR / "strands_runtime.jsonl"
GLOBAL_TRACE_ID = str(uuid.uuid4())


def emit_span(
    span_id,
    parent_span_id,
    agent,
    event,
    status="success",
    token_input=None,
    token_output=None,
    metadata=None
):
    span = {
        "trace_id": GLOBAL_TRACE_ID,
        "span_id": span_id,
        "parent_span_id": parent_span_id,
        "timestamp": datetime.utcnow().isoformat(),
        "agent": agent,
        "event": event,
        "status": status,
        "token_input": token_input,
        "token_output": token_output,
        "metadata": metadata or {}
    }
    with open(TRACE_FILE, "a") as f:
        f.write(json.dumps(span) + "\n")

# %% [markdown]
# In this module we will be creating an orchestrator based multi-agent workflow.
#
# <div style="text-align:left">
#     <img src="images/architecture.png" width="75%" />
# </div>
#
# We will also explore `use_llm` which allows us to create nested agents.

# %% [markdown]
# ## Research Agent

# %% [markdown]
# Let's first create a basic research assistant.

# %%
RESEARCH_ASSISTANT_PROMPT = """You are a specialized research assistant. Focus only on providing
factual, well-sourced information in response to research questions.
Always cite your sources when possible."""

# %%
research_agent = Agent(
    model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    system_prompt=RESEARCH_ASSISTANT_PROMPT,
)

query = "Overview of Amazon Bedrock and its features"
response = research_agent(query)
# Out:
# # Amazon Bedrock Overview
#
# Amazon Bedrock is a fully managed service from AWS that makes foundation models (FMs) from leading AI companies accessible through a unified API. Launched in general availability in September 2023, it's designed to help organizations build and scale generative AI applications.
#
# ## Key Features
#
# ### 1. **Multiple Foundation Models**
# Bedrock provides access to various FMs including:
# - **Anthropic Claude** (Claude 3 family - Opus, Sonnet, Haiku)
# - **Amazon Titan** (Amazon's own models for text and embeddings)
# - **AI21 Labs Jurassic**
# - **Cohere Command and Embed**
# - **Meta Llama 2 and Llama 3**
# - **Stability AI Stable Diffusion** (for image generation)
#
# ### 2. **Model Customization**
# - **Fine-tuning**: Customize models with your own labeled datasets
# - **Continued pre-training**: Adapt models to specific domains with unlabeled data
# - Models remain private to your account
#
# ### 3. **Retrieval-Augmented Generation (RAG)**
# - **Knowledge Bases**: Connect FMs to your data sources
# - Automatically handles data ingestion, vector embeddings, and retrieval
# - Improves accuracy by grounding responses in your proprietary data
#
# ### 4. **Agents**
# - Build autonomous agents that can break down tasks, create orchestration plans, and execute multi-step workflows
# - Integrate with AWS Lambda and other services
# - Can use APIs and take actions on behalf of users
#
# ### 5. **Security and Privacy**
# - Data is encrypted in transit and at rest
# - Your data is not used to train base models
# - VPC support for network isolation
# - AWS PrivateLink compatibility
# - Compliance with SOC, HIPAA, GDPR standards
#
# ### 6. **Guardrails**
# - Content filtering capabilities
# - Define denied topics and word filters
# - PII (Personally Identifiable Information) redaction
# - Helps implement responsible AI practices
#
# ### 7. **Serverless Architecture**
# - No infrastructure to manage
# - Pay-per-use pricing model
# - Automatic scaling
#
# ## Use Cases
# - Chatbots and virtual assistants
# - Content generation and summarization
# - Code generation
# - Search and personalization
# - Image generation and editing
#
# **Sources**: This information is based on AWS official documentation and public announcements about Amazon Bedrock's general availability and features as of 2023-2024.

# %% [markdown]
# Now we can wrap this agent as a tool. Allowing other agents to interact with it.
#
# #### Best Practices for Agent as Tools
#
# When implementing the "Agents as Tools" pattern with Strands Agents:
#
# 1. Clear tool documentation: Write descriptive docstrings that explain the agent's expertise
# 2. Focused system prompts: Keep each specialized agent tightly focused on its domain
# 3. Proper response handling: Use consistent patterns to extract and format responses
# 4. Tool selection guidance: Give the orchestrator clear criteria for when to use each specialized agent

# %%
@tool
def research_assistant(query: str) -> str:

    tool_span_id = str(uuid.uuid4())

    emit_span(
        span_id=tool_span_id,
        parent_span_id="orchestrator_root",
        agent="research_assistant_tool",
        event="tool_invoked",
        metadata={"query": query}
    )

    try:
        research_agent = Agent(
            model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
            system_prompt=RESEARCH_ASSISTANT_PROMPT,
        )

        child_span_id = str(uuid.uuid4())

        emit_span(
            span_id=child_span_id,
            parent_span_id=tool_span_id,
            agent="research_agent",
            event="agent_execution_started",
            metadata={"query": query}
        )

        response = research_agent(query)

        emit_span(
            span_id=child_span_id,
            parent_span_id=tool_span_id,
            agent="research_agent",
            event="agent_execution_completed",
            metadata={"response_size": len(str(response))}
        )

        return str(response)

    except Exception as e:
        emit_span(
            span_id=tool_span_id,
            parent_span_id="orchestrator_root",
            agent="research_assistant_tool",
            event="tool_failed",
            status="failed",
            metadata={"error": str(e)}
        )
        return f"Error in research assistant: {str(e)}"

# %% [markdown]
# Now let's follow the best practices and create `product_recommendation_assistant`, `trip_planning_assistant`, and `orchestrator` agent.

# %% [markdown]
# ### Product Recommendation Assistant

# %%
@tool
def product_recommendation_assistant(query: str) -> str:

    tool_span_id = str(uuid.uuid4())

    emit_span(
        span_id=tool_span_id,
        parent_span_id="orchestrator_root",
        agent="product_recommendation_tool",
        event="tool_invoked",
        metadata={"query": query}
    )

    try:
        product_agent = Agent(
            model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
            system_prompt="""You are a specialized product recommendation assistant.
            Provide personalized product suggestions based on user preferences.
            Always cite your sources.""",
        )

        child_span_id = str(uuid.uuid4())

        emit_span(
            span_id=child_span_id,
            parent_span_id=tool_span_id,
            agent="product_agent",
            event="agent_execution_started",
            metadata={"query": query}
        )

        response = product_agent(query)

        emit_span(
            span_id=child_span_id,
            parent_span_id=tool_span_id,
            agent="product_agent",
            event="agent_execution_completed",
            metadata={"response_size": len(str(response))}
        )

        return str(response)

    except Exception as e:
        emit_span(
            span_id=tool_span_id,
            parent_span_id="orchestrator_root",
            agent="product_recommendation_tool",
            event="tool_failed",
            status="failed",
            metadata={"error": str(e)}
        )
        return f"Error in product recommendation: {str(e)}"

# %% [markdown]
# ### Trip Planning Assistant

# %%
@tool
def trip_planning_assistant(query: str) -> str:

    tool_span_id = str(uuid.uuid4())

    emit_span(
        span_id=tool_span_id,
        parent_span_id="orchestrator_root",
        agent="trip_planning_tool",
        event="tool_invoked",
        metadata={"query": query}
    )

    try:
        travel_agent = Agent(
            model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
            system_prompt="""You are a specialized travel planning assistant.
            Create detailed travel itineraries based on user preferences.""",
        )

        child_span_id = str(uuid.uuid4())

        emit_span(
            span_id=child_span_id,
            parent_span_id=tool_span_id,
            agent="travel_agent",
            event="agent_execution_started",
            metadata={"query": query}
        )

        response = travel_agent(query)

        emit_span(
            span_id=child_span_id,
            parent_span_id=tool_span_id,
            agent="travel_agent",
            event="agent_execution_completed",
            metadata={"response_size": len(str(response))}
        )

        return str(response)

    except Exception as e:
        emit_span(
            span_id=tool_span_id,
            parent_span_id="orchestrator_root",
            agent="trip_planning_tool",
            event="tool_failed",
            status="failed",
            metadata={"error": str(e)}
        )
        return f"Error in trip planning: {str(e)}"

# %% [markdown]
# ### Orchestrator Agent

# %%
# Define orchestrator system prompt with clear tool selection guidance
MAIN_SYSTEM_PROMPT = """
You are an assistant that routes queries to specialized agents:
- For research questions and factual information → Use the research_assistant tool
- For product recommendations and shopping advice → Use the product_recommendation_assistant tool
- For travel planning and itineraries → Use the trip_planning_assistant tool
- For simple questions not requiring specialized knowledge → Answer directly

Always select the most appropriate tool based on the user's query.
"""

# %%
# Strands Agents allows easy integration of agent tools
orchestrator = Agent(
    model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    system_prompt=MAIN_SYSTEM_PROMPT,
    tools=[
        research_assistant,
        product_recommendation_assistant,
        trip_planning_assistant,
        file_write,
    ],
)

# %%
# Example: E-commerce Customer Service System
customer_query = (
    "I'm looking for hiking boots. Write the final response to current directory."
)

os.environ["BYPASS_TOOL_CONSENT"] = "true"

emit_span(
    span_id="orchestrator_root",
    parent_span_id=None,
    agent="orchestrator",
    event="workflow_started",
    metadata={"query": customer_query}
)

response = orchestrator(customer_query)

emit_span(
    span_id="orchestrator_root_end",
    parent_span_id="orchestrator_root",
    agent="orchestrator",
    event="workflow_completed"
)
# Out:
# /var/folders/84/0ydjkq3n6rg9j3wc_fl9y4gw0000gn/T/ipykernel_16852/4141765146.py:27: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat(),
# I'll help you find hiking boots recommendations and save the information to a file.
# Tool #1: product_recommendation_assistant
# # Hiking Boots Recommendations
#
# I'd be happy to help you find the right hiking boots! To give you the best recommendations, let me share some top options across different categories:
#
# ## Top Overall Picks
#
# **1. Salomon X Ultra 4 GTX**
# - **Best for:** Day hiking and light backpacking
# - **Features:** Waterproof Gore-Tex, excellent ankle support, aggressive traction
# - **Price range:** $150-180
# - **Weight:** Lightweight and nimble
#
# **2. Merrell Moab 3 Mid Waterproof**
# - **Best for:** Budget-conscious beginners
# - **Features:** Comfortable out-of-box, reliable waterproofing, durable
# - **Price range:** $130-160
# - **Great value option**
#
# **3. La Sportiva Spire GTX**
# - **Best for:** Technical terrain and experienced hikers
# - **Features:** Superior stability, climbing-zone toe, Italian craftsmanship
# - **Price range:** $200-230
#
# **4. Lowa Renegade GTX Mid**
# - **Best for:** Multi-day backpacking with heavy loads
# - **Features:** Exceptional support, very durable, European comfort fit
# - **Price range:** $230-280
#
# ## Key Factors to Consider
#
# - **Terrain type:** Day trails vs. rocky/technical terrain
# - **Load weight:** Light day pack vs. multi-day backpacking gear
# - **Climate:** Waterproof vs. breathable mesh
# - **Fit:** Wide, narrow, or standard widths available
#
# **What would help me narrow this down for you?**
# - What type of hiking are you planning?
# - What's your budget range?
# - Any foot fit considerations (wide/narrow)?
#
# *Note: I'm providing general recommendations based on common product knowledge. For the most current models and pricing, I recommend checking with outdoor retailers or manufacturer websites directly.*Now I'll save this information to a file in the current directory.
# Tool #2: file_write
# ╔═════════ File Write Operation ═════════╗
# ║                                        ║
# ║ Path: hiking_boots_recommendations.txt ║
# ║ Size: 1631 characters                  ║
# ║                                        ║
# ╚════════════════════════════════════════╝
# ╔══════════════════════ Write Successful ═══════════════════════╗
# ║ File written successfully to hiking_boots_recommendations.txt ║
# ╚═══════════════════════════════════════════════════════════════╝
# Perfect! I've gathered hiking boots recommendations and saved them to **hiking_boots_recommendations.txt** in your current directory. The file includes:
#
# - 4 top hiking boot recommendations across different categories (day hiking, budget-friendly, technical terrain, and heavy backpacking)
# - Key features, price ranges, and best use cases for each boot
# - Important factors to consider when choosing hiking boots
#
# Feel free to review the file, and if you'd like more specific recommendations based on your hiking plans, budget, or fit requirements, just let me know!

# %% [markdown]
# Let's look at the messages of the orchestrator. Here you can see the agent decided to use the sub-agent as tool.

# %%
orchestrator.messages
# Out:
# [{'role': 'user',
#   'content': [{'text': "I'm looking for hiking boots. Write the final response to current directory."}]},
#  {'role': 'assistant',
#   'content': [{'text': "I'll help you find hiking boots recommendations and save the information to a file."},
#    {'toolUse': {'toolUseId': 'tooluse_BCVOoUHbdujh1zI3sMGkmc',
#      'name': 'product_recommendation_assistant',
#      'input': {'query': 'hiking boots recommendations'}}}],
#   'metadata': {'usage': {'inputTokens': 888,
#     'outputTokens': 74,
#     'totalTokens': 962},
#    'metrics': {'latencyMs': 2636, 'timeToFirstByteMs': 1892}}},
#  {'role': 'user',
#   'content': [{'toolResult': {'toolUseId': 'tooluse_BCVOoUHbdujh1zI3sMGkmc',
#      'status': 'success',
#      'content': [{'text': "# Hiking Boots Recommendations\n\nI'd be happy to help you find the right hiking boots! To give you the best recommendations, let me share some top options across different categories:\n\n## Top Overall Picks\n\n**1. Salomon X Ultra 4 GTX**\n- **Best for:** Day hiking and light backpacking\n- **Features:** Waterproof Gore-Tex, excellent ankle support, aggressive traction\n- **Price range:** $150-180\n- **Weight:** Lightweight and nimble\n\n**2. Merrell Moab 3 Mid Waterproof**\n- **Best for:** Budget-conscious beginners\n- **Features:** Comfortable out-of-box, reliable waterproofing, durable\n- **Price range:** $130-160\n- **Great value option**\n\n**3. La Sportiva Spire GTX**\n- **Best for:** Technical terrain and experienced hikers\n- **Features:** Superior stability, climbing-zone toe, Italian craftsmanship\n- **Price range:** $200-230\n\n**4. Lowa Renegade GTX Mid**\n- **Best for:** Multi-day backpacking with heavy loads\n- **Features:** Exceptional support, very durable, European comfort fit\n- **Price range:** $230-280\n\n## Key Factors to Consider\n\n- **Terrain type:** Day trails vs. rocky/technical terrain\n- **Load weight:** Light day pack vs. multi-day backpacking gear\n- **Climate:** Waterproof vs. breathable mesh\n- **Fit:** Wide, narrow, or standard widths available\n\n**What would help me narrow this down for you?**\n- What type of hiking are you planning?\n- What's your budget range?\n- Any foot fit considerations (wide/narrow)?\n\n*Note: I'm providing general recommendations based on common product knowledge. For the most current models and pricing, I recommend checking with outdoor retailers or manufacturer websites directly.*\n"}]}}]},
#  {'role': 'assistant',
#   'content': [{'text': "Now I'll save this information to a file in the current directory."},
#    {'toolUse': {'toolUseId': 'tooluse_gkMukVS6EymfxkmBJu4Nc2',
#      'name': 'file_write',
#      'input': {'path': 'hiking_boots_recommendations.txt',
#       'content': "# Hiking Boots Recommendations\n\nI'd be happy to help you find the right hiking boots! To give you the best recommendations, let me share some top options across different categories:\n\n## Top Overall Picks\n\n**1. Salomon X Ultra 4 GTX**\n- **Best for:** Day hiking and light backpacking\n- **Features:** Waterproof Gore-Tex, excellent ankle support, aggressive traction\n- **Price range:** $150-180\n- **Weight:** Lightweight and nimble\n\n**2. Merrell Moab 3 Mid Waterproof**\n- **Best for:** Budget-conscious beginners\n- **Features:** Comfortable out-of-box, reliable waterproofing, durable\n- **Price range:** $130-160\n- **Great value option**\n\n**3. La Sportiva Spire GTX**\n- **Best for:** Technical terrain and experienced hikers\n- **Features:** Superior stability, climbing-zone toe, Italian craftsmanship\n- **Price range:** $200-230\n\n**4. Lowa Renegade GTX Mid**\n- **Best for:** Multi-day backpacking with heavy loads\n- **Features:** Exceptional support, very durable, European comfort fit\n- **Price range:** $230-280\n\n## Key Factors to Consider\n\n- **Terrain type:** Day trails vs. rocky/technical terrain\n- **Load weight:** Light day pack vs. multi-day backpacking gear\n- **Climate:** Waterproof vs. breathable mesh\n- **Fit:** Wide, narrow, or standard widths available\n\n**What would help me narrow this down for you?**\n- What type of hiking are you planning?\n- What's your budget range?\n- Any foot fit considerations (wide/narrow)?\n\n*Note: I'm providing general recommendations based on common product knowledge. For the most current models and pricing, I recommend checking with outdoor retailers or manufacturer websites directly.*"}}}],
#   'metadata': {'usage': {'inputTokens': 1410,
#     'outputTokens': 526,
#     'totalTokens': 1936},
#    'metrics': {'latencyMs': 6170, 'timeToFirstByteMs': 2286}}},
#  {'role': 'user',
#   'content': [{'toolResult': {'toolUseId': 'tooluse_gkMukVS6EymfxkmBJu4Nc2',
#      'status': 'success',
#      'content': [{'text': 'File write success: File written successfully to hiking_boots_recommendations.txt'}]}}]},
#  {'role': 'assistant',
#   'content': [{'text': "Perfect! I've gathered hiking boots recommendations and saved them to **hiking_boots_recommendations.txt** in your current directory. The file includes:\n\n- 4 top hiking boot recommendations across different categories (day hiking, budget-friendly, technical terrain, and heavy backpacking)\n- Key features, price ranges, and best use cases for each boot\n- Important factors to consider when choosing hiking boots\n\nFeel free to review the file, and if you'd like more specific recommendations based on your hiking plans, budget, or fit requirements, just let me know!"}],
#   'metadata': {'usage': {'inputTokens': 1963,
#     'outputTokens': 120,
#     'totalTokens': 2083},
#    'metrics': {'latencyMs': 3833, 'timeToFirstByteMs': 1608}}}]

# %%
customer_query = "Can you help me plan my trip to Patagonia"

emit_span(
    span_id="orchestrator_root",
    parent_span_id=None,
    agent="orchestrator",
    event="workflow_started",
    metadata={"query": customer_query}
)

response = orchestrator(customer_query)

emit_span(
    span_id="orchestrator_root_end",
    parent_span_id="orchestrator_root",
    agent="orchestrator",
    event="workflow_completed"
)
# Out:
# /var/folders/84/0ydjkq3n6rg9j3wc_fl9y4gw0000gn/T/ipykernel_16852/4141765146.py:27: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat(),
# Tool #3: trip_planning_assistant
# # Patagonia Adventure Itinerary
#
# ## Trip Overview
# **Duration:** 10-12 days
# **Best Time to Visit:** November-March (Patagonian summer)
# **Region:** Chilean & Argentine Patagonia
#
# ---
#
# ## **Day 1-3: El Calafate & Perito Moreno Glacier (Argentina)**
#
# ### Day 1: Arrival
# - Fly into El Calafate (FTE airport)
# - Check into hotel in town
# - Evening walk along Lago Argentino waterfront
# - **Stay:** El Calafate town
#
# ### Day 2: Perito Moreno Glacier
# - Full-day excursion to Perito Moreno Glacier
# - Walk the boardwalks for stunning glacier views
# - Optional: Ice trekking on the glacier (book in advance)
# - **Stay:** El Calafate
#
# ### Day 3: Upsala & Spegazzini Glaciers
# - Boat tour through icebergs to remote glaciers
# - Alternative: Visit Glaciarium museum
# - **Stay:** El Calafate
#
# ---
#
# ## **Day 4-7: Torres del Paine National Park (Chile)**
#
# ### Day 4: Transfer to Puerto Natales
# - 5-hour bus ride to Chile
# - Cross border at Cerro Castillo
# - Explore Puerto Natales town
# - **Stay:** Puerto Natales
#
# ### Day 5-6: Torres del Paine
# - Enter the park (arrive early)
# - **Hike options:**
#   - Base of Torres trail (8-10 hours round trip)
#   - Grey Glacier viewpoint (shorter option)
#   - Salto Grande waterfall
# - Wildlife spotting: guanacos, condors, foxes
# - **Stay:** Refugio/campsite inside park OR Puerto Natales
#
# ### Day 7: More Torres del Paine
# - Visit Lago Pehoé viewpoint
# - French Valley trail (if time permits)
# - Nordenskjöld Lake scenic drive
# - **Stay:** Puerto Natales
#
# ---
#
# ## **Day 8-10: El Chaltén (Argentina)**
#
# ### Day 8: Travel to El Chaltén
# - Return to Argentina via bus (6-7 hours)
# - Settle into Argentina's trekking capital
# - **Stay:** El Chaltén
#
# ### Day 9: Fitz Roy Hike
# - Trek to Laguna de los Tres for Fitz Roy views
# - 8-10 hours round trip (challenging but rewarding)
# - Sunrise departure recommended
# - **Stay:** El Chaltén
#
# ### Day 10: Laguna Torre
# - Hike to Laguna Torre & Cerro Torre viewpoint
# - 6-7 hours round trip (moderate)
# - Afternoon: Craft beer at local brewery
# - **Stay:** El Chaltén
#
# ---
#
# ## **Day 11-12: Departure**
#
# ### Day 11: Return to El Calafate
# - 3-hour bus ride
# - Last-minute shopping for souvenirs
# - **Stay:** El Calafate
#
# ### Day 12: Fly Home
# - Depart from El Calafate airport
#
# ---
#
# ## Essential Tips
#
# ### Packing
# - Layered clothing (weather changes rapidly)
# - Waterproof jacket & pants
# - Sturdy hiking boots (broken in)
# - Sun protection (UV is intense)
# - Reusable water bottle
#
# ### Budget Considerations
# - **Budget:** $80-120/day (hostels, buses, self-catering)
# - **Mid-range:** $150-250/day (hotels, tours, restaurants)
# - **Luxury:** $400+/day (high-end lodges, private guides)
#
# ### Booking Advice
# - Book accommodations 2-3 months ahead for peak season
# - Reserve glacier tours and park refugios early
# - Chilean pesos & Argentine pesos both needed
#
# ### Transportation
# - Buses connect all major towns (comfortable, affordable)
# - Rental car gives flexibility (4WD recommended)
#
# ---
#
# **Questions about specific activities, accommodation preferences, or budget adjustments?**Great! I've created a comprehensive 10-12 day itinerary for your Patagonia trip covering both Argentine and Chilean Patagonia. Here's what's included:
#
# ## Trip Highlights:
#
# **🇦🇷 Argentina Side:**
# - Perito Moreno Glacier and ice trekking
# - El Chaltén hiking (Fitz Roy and Cerro Torre)
# - El Calafate as your base
#
# **🇨🇱 Chile Side:**
# - Torres del Paine National Park
# - Iconic trails and viewpoints
# - Puerto Natales town
#
# ## Key Information:
# - **Best time:** November-March (summer)
# - **Duration:** 10-12 days
# - **Budget range:** $80-400+/day depending on style
# - **Activities:** Glacier tours, world-class hiking, wildlife viewing
#
# The itinerary includes daily breakdowns, accommodation suggestions, hiking options, transportation tips, and packing recommendations.
#
# **Would you like me to:**
# - Adjust the itinerary length or focus on specific areas?
# - Provide more detail on accommodations or restaurants?
# - Help with a specific budget range?
# - Add adventure activities (kayaking, ice climbing, horseback riding)?
# - Save this itinerary to a file?
#
# Let me know how I can customize this further for your trip!

# %% [markdown]
# ### Calling multiple agents

# %%
orchestrator.messages = []

# %%
query = "Can you do a research on spain? Also help me plan a 7 day trip."

emit_span(
    span_id="orchestrator_root",
    parent_span_id=None,
    agent="orchestrator",
    event="workflow_started",
    metadata={"query": query}
)

orchestrator(query)

emit_span(
    span_id="orchestrator_root_end",
    parent_span_id="orchestrator_root",
    agent="orchestrator",
    event="workflow_completed"
)
# Out:
# /var/folders/84/0ydjkq3n6rg9j3wc_fl9y4gw0000gn/T/ipykernel_16852/4141765146.py:27: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat(),
# I'll help you with both research on Spain and planning a 7-day trip there!
# Tool #4: research_assistant
#
# Tool #5: trip_planning_assistant
# # 🇪🇸 7-Day Spain Travel Itinerary
#
# ## **Trip Overview:# Spain: Madrid & Barcelona Comprehensive Overview
#
# ## General Information
#
# **Official Highlights Name:** Kingdom of Spain (**
#
# ThisReino it de España)inerary covers
# **Capital:** Madrid
# **Population:** Spain's two Approximately 47.4 most iconic cities with million (2023) a perfect blend of culture
# **Official Language:** Spanish (, cuisineCastilian);, and architecture co.-official regional
#
# --- languages include
#
# ##  Catalan, Galician, and📅 **Day- Basque
# **Governmentby-Day It:**inerary**
#
# ### **Days Parliamentary 1-3: Madrid** constitutional monarchy
# **Currency:** Euro (EUR)
#
# **Day
# **EU 1 - Member:** Since Arrival & Historic 1 Center**
# - Morning986: Arrive in
#
# ## Geography
#
# **Location Madrid,:** Southwestern Europe, occup check into hotel
# - Afternoon: Exploreying most of the Iberian Peninsula
# **Area Pu:** 505,990 kmerta del Sol, Plaza² (195 Mayor,360 sq
# - Evening: Dinner in mi) La -  Latina4 neighborhoodth largest country in Europe
# **,Borders try:** Portugal ( tapwest), France andas at Andorra (north), Gibraltar ( Casasouth) Lucas
# **Coastline:** Mediterranean Sea (
#
# **Day 2 - Arteast & Culture**
# - Morning:/ Psoutheast), Atlantic Ocean (northrado Museum (book/northwest tickets online))
# - Afternoon: Ret
#
# **iro Park,Key Crystal Geographic Features:**
# - **Meseta Central:** High central plateau averaging 610m elevation
# - **Mountain Ranges:** Pyrenees (north), Sierra Nevada (south), Cantabrian Mountains
# - **Rivers:** Tagus, Ebro, Duero, Guadalquivir Palace
# - Evening: Gran Vía shopping &
# - **Islands rooftop sunset at Círculo de Bellas Artes
#
# **Day 3 - Royal Madrid**
# - Morning: Royal Palace & Almudena Cathedral
# - Afternoon::** Ba Templo de Debod (Egyptian temple),learic Islands (Mediterranean sunset), Canary Islands (Atlantic) views
# - Evening: Fl
# - **Climateamenco show in Tabl:** Variesao Las from oceanic ( Carbonnortheras
#
# ###) to Mediterranean (coast **Days 4-7): Barcelona**
#
# **Day 4 to semi - Travel-arid (interior &)
#
# ## History Gothic
#
# **Ancient Period Quarter**
# - Morning: High:**-speed train to Barcelona
# - Pre (2-Roman civil.5 hours)
# -izations: Afternoon: Gothic Iber Quarter walkingians, Celts, Phoen tour,icians, Barcelona Greeks
# - Roman Cathedral
# - Evening: Dinner at Hisp El Born neighborhoodania (
#
# **Day 5 -218 Gaudí Day**
# - Morning: Sagrada BCE Familia ( - 5preth century CE)
# --book t Visigothic Kingdom (5imed entry!)th-8
# - Afternoon: Park Güth centuries)ell
#
# **Medieval Period:**
# - Muslim conquest
# - Evening: Pas (711seig de Gràcia - CE) Casa - Al Batlló & Casa-Andalus era Milà exterior
# - views Reconquista (718
#
# **Day 6 - Beach-1492): & Christian recon Montquestjuïc**
# - Morning
# - : Barcel1oneta Beach,469: Marriage seaf of Ferdinandood lunch
# - Afternoon: of Montjuïc Castle Aragon and Isabella of Cast, Magicile unified Fountain
# - Evening: Tap Spain
#
# **Imperialas tour Era in El:**
# -  Raval
#
# **Day 71492 - Markets: Columbus & Departure reaches**
# - Morning: La Americas; Boqueria Market completion, of Reconquista
# - 16 Las Ramblas
# - Afternoonth-: Last17-minute shopping,th centuries: Spanish prepare Golden Age - for vast departure empire
# - 1
# - Evening: De588part from: Barcelona
#
# ---
#
# ##  Defeat🏨 **Accommodation Suggestions** of Spanish
#
# ### **Madrid Armada
# - ( Grad3ual decline through  18th-nights)**
# - **Budget19th centuries
#
# **:** TOModern PeriodC:**
# - 1936 Hostel Madrid (€-251939: Spanish Civil War
# -- 193940-1975: Franco dictatorship/night)
# - 1975: Death of - Social Franco; transition atmosphere, central to democracy
# - 1978
# - **Mid-Range: New:** Hotel democratic Mod constitution
# - 1982: NATOerno membership
# - 1986: EU Pu membership
#
# ## Culture
#
# **Artserta del Sol (€80-120 &/night) - Prime Literature location:**
# - Literary
# - **Luxury:** Hotel Fen giantsix Gran: Cervantes (* MeDon Quixote*),liá ( L€200orca-300/night) - , Mach5-star elegadoance
#
# ### **Barcelona (3
# - Artistsnights)**
# - **Budget:** Sant: Jor Velázquez, Goya,di Hostels Picasso, Dalí, (€30-45/night) Mi - Cleanró
# - Architecture, young: G vibe
# - **Mid-Rangeaudí's:** Hotel Jazz modern (isme€100, Moor-150/night) - Roish influences (oftop poolAlhambra),
#
# **Traditions central
# - **Luxury:**:**
# - ** MaFlamenco:** Andaljestic Hotel &usian music Spa (€250-400/ and dance formnight) - Pas
# - **Bullfighting:**se Traditionalig de Gràcia location but
#
# ** controversialTip:** Book neighborhoods spect likeacle
# - **Fiestas Mal:** Laasaña ( Tomatina, RunningMadrid of the Bulls () or ElSan Born Fermín), (Barcelona) for authentic Fallas local experiences.
#
# ---
#
# ##
# - **Si🎯 **Must-See Destinationsesta:** Traditional**
#
# ### **Madrid**
# 1 afternoon rest period (. **lessPrado Museum** - common today World-)
#
# **Cuisine:**
# -class art collection ( Tapas culture,Vel paella, jamázón ibérico,quez, Goya) gazpacho
# - Regional
# 2. **Royal Palace** - diversity Europe: Bas's largestque pint royal palacexos, Galician seafood
# 3. **Ret, Catalan cuisineiro Park** -
# - World300-renowned wine regions: La+ acres of gardens Rioja, Ribera del and monuments Duero, Priorat
# 4. **Merc
#
# ## Notable Cities
#
# **Madrid**ado de (3 San Miguel** - G.3ourmet food market million)
# - Capital and
#
# ### **Barcelona**
# 1. ** largest city
# - CulturalSagrada Familia** - center: Gaudí's un Pfinished masterpiece
# 2. **rado MuseumPark Güell** - Wh, Royal Palaceimsical mos
# - Financialaic park hub
# 3. **Gothic
#
# **Barcelona** (1 Quarter** - Medieval.6 million)
# - streets Catal andonia's Roman capital
# - Mediterranean ruins port
# 4. **La Boqu city
# -eria** G - Iconicaudí's food market Sagrada Família,
# 5. **Montser Gothicrat** Quarter (
# - MajorOptional tourist day destination
#
# **Valencia trip) - Mountain** (800 monastery,000)
# - Mediterranean
#
# --- coast
#
# ## 💡
# - City **Essential of Arts and Sciences
# - Origin Travel Tips**
#
# ### **Before of pa You Go**ella
#
# **Seville** (
# - **Visa:** Check688 requirements (,000)
# - Andalusian capital
# - MoorSchengen zoneish heritage:) Alcázar, Gi
# - **Currencyralda tower:** Euro (€
# - Flamenco heart)land
#
# ** - CardsBil widelybao** (345 accepted
# - **Language,000)
# -:** Learn Basque Country basic Spanish phrases;
# - Guggenheim Museum transformed English spoken the in tourist areas
# - **Power city
# - Industrial:** and Type port C city
#
# **Granada,/ MálF plugaga, Zs, aragoza, Córdoba** -230V other
#
# ### **Transportation significant**
# - **Between cities
#
# ## Key Facts
#
# **Economy cities:** Ren:**
# - fe high-speed trains (14bookth largest economy globally  (2+ weeks ahead forGDP disc)ounts)
# - **Within cities:**
# - Major Metro is sectors efficient and cheap (: tourism, manufacturing€, agriculture,10 renewable  energy
# - Worldfor's 2 10nd most- visited country (ride83 card)
# - **Airport+ transfers:** Metro million tourists or annually) A
# - Leadingerobus in producer both of olive cities ( oil and€5 wine
#
# **UNESCO-7 World Heritage Sites:**)
#
# ### **Money49-Saving Tips**
# - sites (3 Eat "rdmenu most in del día" (lunch the special world))
#
# **Sports for:**
# - Football €10-15
# - Free (soccer) museum is national entry: passion Prado (
# - Real Madrid andMon FC-Sat 6 Barcelona among- world8pm's most successful), clubs
# - National many team others:  on2010 World Cup, Sundays
# - Buy 2008 attraction & passes 2012 European Championships
#
# ** ifDemographics visiting:**
# - Life  expectancy: 83+3 years (+ sitesone of world's highest
#
# ###)
# - Highly **Cultural urban Tipsized (**
# - **80Dining% live times in cities)
# - Aging population:** Lunch 2 with-4pm, low Dinner 9 birth rate-11pm
# - **Si
#
# **esta:** SomeRegional shops Diversity close 2-5:**
# - pm17 autonomous communities with
# - **Tipping:** Not mandatory varying degrees of self;-governance
# - Strong regional ident round up or leave 5-10%ities (Catalonia, Basque Country
# - **Gr, Galeetings:** Twoicia)
# - Ongoing kisses ( politicalcheek-to debates about-cheek)
#
# ### regional **Safety** autonomy
#
# Spain
# - Watch represents for a pickpockets in tourist areas and unique metro blend of ancient traditions and modern European
# - Keep society valu, with remarkableables in cultural diversity and historical hotel safe significance that
# - Emergency continues to influence global culture number.: 112
#
# ### **Food to Try**
# - **Madrid:** Cocido madrileño, bocadillo de calamares, churros con chocolate
# - **Barcelona:** Pa amb tomàquet, patatas bravas, crema catalana
# - **Both:** Jamón ibérico, paella (lunch only!), cava, vermouth
#
# ### **Best Time to Visit**
# - **Spring (April-June)** or **Fall (September-October)** - Perfect weather, fewer crowds
# - Avoid August (very hot, locals on vacation)
#
# ---
#
# ## 📱 **Useful Apps**
# - **Renfe** - Train tickets
# - **Moovit/Citymapper** - Public transport navigation
# - **The Fork** - Restaurant reservations & discounts
# - **Google Translate** - Offline Spanish
#
# ---
#
# ## 💰 **Estimated Budget** (per person)
# - **Budget:** €70-100/day
# - **Mid-Range:** €150-200/day
# - **Luxury:** €300+/day
#
# *(Includes accommodation, food, local transport, and attractions)*
#
# ---
#
# **¡Buen viaje!** Enjoy your Spanish adventure! 🌞🥘Perfect! I've gathered comprehensive information about Spain and created a 7-day trip plan for you. Here's what I found:
#
# ## Research on Spain - Key Highlights:
#
# **Geography & Location:** Spain is located in southwestern Europe on the Iberian Peninsula, with beautiful coastlines along both the Mediterranean and Atlantic, plus the Balearic and Canary Islands.
#
# **Rich History:** From Roman Hispania to Muslim Al-Andalus, the Reconquista, a vast colonial empire, and eventually modern democracy after Franco's dictatorship ended in 1975.
#
# **Cultural Treasures:** Home to legendary artists like Picasso, Dalí, and Gaudí, plus literary giants like Cervantes. Spain has 49 UNESCO World Heritage Sites (3rd most in the world)!
#
# **Tourism Powerhouse:** The 2nd most visited country globally with 83+ million tourists annually.
#
# ## Your 7-Day Trip Plan:
#
# The itinerary focuses on Spain's two most iconic cities:
#
# **Days 1-3: Madrid**
# - Historic center (Puerta del Sol, Plaza Mayor)
# - World-class art at the Prado Museum
# - Royal Palace and beautiful Retiro Park
# - Authentic flamenco show
#
# **Days 4-7: Barcelona**
# - Gothic Quarter's medieval charm
# - Gaudí's architectural masterpieces (Sagrada Familia, Park Güell)
# - Beach time at Barceloneta
# - Vibrant markets and tapas tours
#
# **Key Travel Tips:**
# - 🚄 Take the high-speed train between cities (2.5 hours)
# - 🍽️ Eat lunch 2-4pm, dinner 9-11pm (Spanish schedule!)
# - 💰 Budget €70-200/day depending on your style
# - 🎟️ Pre-book Sagrada Familia tickets
# - ⚠️ Watch for pickpockets in tourist areas
#
# Would you like me to adjust the itinerary for different cities (like adding Seville or Valencia), or would you like more specific information about any aspect of Spain?

# %% [markdown]
# Behind the scenes, the orchestrator will:
# 1. First call the `research_assistant`
# 2. Then call `trip_planning_assistant`
# 3. Combine these specialized responses into a cohesive answer that addresses both queries

# %% [markdown]
# ### Sequential Agent Communication Pattern

# %% [markdown]
# The agent tool can also combine multiple agents together. In this example we will provide output of `research_agent` to `summary_agent` and return the summarized response.

# %%
# define the user query
topic = "generative Ai"
# Create a research agent
research_agent = Agent(
    model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    system_prompt=RESEARCH_ASSISTANT_PROMPT,
)
# Create a summarization agent
summary_agent = Agent(
    model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    system_prompt="""
    You are a summarization specialist focused on distilling complex information into clear, concise summaries.
    Your primary goal is to take detailed information and extract the key points, main arguments, and critical data.
    You should maintain the accuracy of the original content while making it more digestible.
    Focus on clarity, brevity, and highlighting the most important aspects of the information.
    """,
)

print("Multiple agents created successfully!")
print(f"\n🔍 RESEARCH AGENT working on: {topic}\n") 
try:
    research_response = research_agent(
        f"Please gather comprehensive information about {topic}."
    )
    research_text = research_response.message['content'][0]["text"]
    print("\n✂️ SUMMARY AGENT distilling the research\n")
    
    summary_response = summary_agent(
        f"Please create a concise summary of this research: {research_text}"
    )
    summary_text = summary_response.message['content'][0]["text"]
    print(summary_text)
except Exception as e:
    print(f"Error in research assistant: {str(e)}")
# Out:
# Multiple agents created successfully!
#
# 🔍 RESEARCH AGENT working on: generative Ai
#
# # Comprehensive Information About Generative AI
#
# ## Definition and Core Concept
#
# Generative AI refers to artificial intelligence systems capable of creating new content—including text, images, audio, video, code, and synthetic data—based on patterns learned from training data. Unlike traditional AI that recognizes patterns or makes predictions, generative AI produces novel outputs that mimic human-created content.
#
# ## Key Technologies and Models
#
# ### Large Language Models (LLMs)
# - **GPT (Generative Pre-trained Transformer)** series by OpenAI
# - **BERT** and **LaMDA** by Google
# - **Claude** by Anthropic
# - **LLaMA** by Meta
# - These models use transformer architecture with billions of parameters
#
# ### Image Generation Models
# - **Diffusion Models**: DALL-E, Stable Diffusion, Midjourney
# - **GANs (Generative Adversarial Networks)**: Earlier technology using competing neural networks
# - **VAEs (Variational Autoencoders)**: Used for image generation and manipulation
#
# ### Audio and Video Models
# - Text-to-speech systems
# - Music generation (e.g., MusicLM)
# - Video generation (e.g., Runway, Sora)
#
# ## How Generative AI Works
#
# ### Training Process
# 1. **Data Collection**: Models trained on massive datasets (text, images, etc.)
# 2. **Pattern Recognition**: Neural networks identify statistical patterns
# 3. **Parameter Optimization**: Billions of parameters adjusted through training
# 4. **Fine-tuning**: Models refined for specific tasks
#
# ### Generation Process
# - Uses learned patterns to predict and generate new content
# - Transformer architecture processes input through attention mechanisms
# - Outputs generated token-by-token (for text) or through iterative refinement (for images)
#
# ## Applications
#
# ### Business and Enterprise
# - Content creation and marketing
# - Customer service chatbots
# - Code generation and software development
# - Document summarization and analysis
# - Data synthesis for testing
#
# ### Creative Industries
# - Art and design generation
# - Music composition
# - Writing assistance
# - Video game content creation
# - Advertising and media production
#
# ### Scientific and Technical
# - Drug discovery and protein folding
# - Scientific research assistance
# - Synthetic data generation
# - Mathematical problem-solving
#
# ### Education
# - Personalized tutoring
# - Educational content creation
# - Language learning
# - Assessment generation
#
# ## Benefits
#
# 1. **Productivity Enhancement**: Automates time-consuming creative tasks
# 2. **Accessibility**: Democratizes content creation for non-experts
# 3. **Personalization**: Creates customized content at scale
# 4. **Innovation**: Enables new forms of creative expression
# 5. **Cost Reduction**: Reduces production costs for various content types
# 6. **Speed**: Generates content in seconds vs. hours/days
#
# ## Challenges and Limitations
#
# ### Technical Limitations
# - **Hallucinations**: Models may generate false or nonsensical information
# - **Bias**: Reflects biases present in training data
# - **Context limitations**: Limited understanding of long-term context
# - **Inconsistency**: May produce varying quality outputs
#
# ### Ethical Concerns
# - **Misinformation**: Potential for creating deepfakes and false content
# - **Copyright issues**: Questions about ownership of AI-generated content
# - **Job displacement**: Concerns about automation of creative work
# - **Privacy**: Training data may include personal information
# - **Environmental impact**: Significant energy consumption for training
#
# ### Security Risks
# - Potential for malicious use (scams, fraud)
# - Data poisoning attacks
# - Prompt injection vulnerabilities
#
# ## Regulatory Landscape
#
# ### Current and Proposed Regulations
# - **EU AI Act**: Comprehensive regulation categorizing AI by risk level
# - **US Executive Orders**: Focusing on safety, security, and transparency
# - **China's regulations**: Strict content control and registration requirements
# - Industry self-regulation efforts
#
# ### Key Regulatory Concerns
# - Transparency and explainability
# - Data privacy and protection
# - Content authentication and watermarking
# - Intellectual property rights
#
# ## Market and Economic Impact
#
# ### Market Size
# - Global generative AI market valued at billions (estimates vary: $10-40 billion in 2023)
# - Projected to grow at 30-40% CAGR through 2030
# - Major investments from tech companies
#
# ### Industry Adoption
# - Rapid adoption across sectors
# - Integration into existing software platforms
# - New startups focused on specific applications
#
# ## Future Trends
#
# ### Technical Developments
# - **Multimodal models**: Combining text, image, audio, video
# - **Improved efficiency**: Smaller models with better performance
# - **Better reasoning**: Enhanced logical and mathematical capabilities
# - **Personalization**: Models adapted to individual users
#
# ### Emerging Applications
# - Scientific discovery acceleration
# - Healthcare diagnostics and treatment planning
# - Climate modeling and sustainability
# - Education transformation
#
# ### Challenges to Address
# - Reducing computational costs
# - Improving accuracy and reliability
# - Developing robust safety measures
# - Establishing ethical frameworks
#
# ## Notable Organizations and Research
#
# ### Leading Companies
# - OpenAI (GPT series, DALL-E)
# - Google DeepMind (Gemini, Bard)
# - Anthropic (Claude)
# - Meta (LLaMA)
# - Microsoft (integration with OpenAI)
# - Stability AI (Stable Diffusion)
#
# ### Research Institutions
# - Stanford AI Lab
# - MIT CSAIL
# - UC Berkeley AI Research
# - Carnegie Mellon University
#
# ## Best Practices for Use
#
# 1. **Verify outputs**: Always fact-check generated content
# 2. **Understand limitations**: Know what the technology can and cannot do
# 3. **Ethical use**: Consider implications of generated content
# 4. **Transparency**: Disclose when content is AI-generated
# 5. **Human oversight**: Maintain human review of critical outputs
# 6. **Data privacy**: Be cautious with sensitive information
#
# ---
#
# **Note**: This field is rapidly evolving. For the most current information, consult recent academic publications, industry reports, and announcements from leading AI organizations. Key sources include arXiv.org for research papers, company blogs (OpenAI, Google AI, etc.), and industry analysts (Gartner, McKinsey, etc.).
# ✂️ SUMMARY AGENT distilling the research
#
# # Generative AI Research Summary
#
# ## Core Definition
# Generative AI systems create novel content (text, images, audio, video, code) by learning patterns from training data, distinguishing themselves from traditional AI by producing original outputs rather than just recognizing patterns.
#
# ## Key Technologies
# - **LLMs**: GPT, BERT, Claude, LLaMA using transformer architecture with billions of parameters
# - **Image Models**: Diffusion models (DALL-E, Stable Diffusion), GANs, VAEs
# - **Audio/Video**: Text-to-speech, music generation, video synthesis tools
#
# ## How It Works
# Models train on massive datasets to identify patterns, optimize billions of parameters, then generate content through learned statistical relationships—text token-by-token or images through iterative refinement.
#
# ## Primary Applications
# - **Business**: Content creation, chatbots, code generation, document analysis
# - **Creative**: Art, music, writing assistance, game development
# - **Scientific**: Drug discovery, research assistance, synthetic data
# - **Education**: Personalized tutoring, content creation
#
# ## Key Benefits
# Productivity enhancement, democratized content creation, personalization at scale, cost reduction, and rapid output generation.
#
# ## Major Challenges
# - **Technical**: Hallucinations, bias, context limitations, inconsistent quality
# - **Ethical**: Misinformation/deepfakes, copyright concerns, job displacement, privacy issues
# - **Security**: Malicious use potential, data poisoning, prompt injection vulnerabilities
# - **Environmental**: High energy consumption
#
# ## Regulatory Environment
# EU AI Act, US Executive Orders, and China's regulations focus on transparency, data privacy, content authentication, and IP rights.
#
# ## Market Impact
# Market valued at $10-40B (2023), projected 30-40% CAGR through 2030, with rapid cross-sector adoption and significant tech investment.
#
# ## Future Outlook
# Multimodal integration, improved efficiency and reasoning, enhanced personalization, with applications expanding into scientific discovery, healthcare, climate modeling, and education transformation.
#
# ## Best Practices
# Verify outputs, understand limitations, ensure ethical use, maintain transparency about AI-generated content, implement human oversight, and protect data privacy.# Generative AI Research Summary
#
# ## Core Definition
# Generative AI systems create novel content (text, images, audio, video, code) by learning patterns from training data, distinguishing themselves from traditional AI by producing original outputs rather than just recognizing patterns.
#
# ## Key Technologies
# - **LLMs**: GPT, BERT, Claude, LLaMA using transformer architecture with billions of parameters
# - **Image Models**: Diffusion models (DALL-E, Stable Diffusion), GANs, VAEs
# - **Audio/Video**: Text-to-speech, music generation, video synthesis tools
#
# ## How It Works
# Models train on massive datasets to identify patterns, optimize billions of parameters, then generate content through learned statistical relationships—text token-by-token or images through iterative refinement.
#
# ## Primary Applications
# - **Business**: Content creation, chatbots, code generation, document analysis
# - **Creative**: Art, music, writing assistance, game development
# - **Scientific**: Drug discovery, research assistance, synthetic data
# - **Education**: Personalized tutoring, content creation
#
# ## Key Benefits
# Productivity enhancement, democratized content creation, personalization at scale, cost reduction, and rapid output generation.
#
# ## Major Challenges
# - **Technical**: Hallucinations, bias, context limitations, inconsistent quality
# - **Ethical**: Misinformation/deepfakes, copyright concerns, job displacement, privacy issues
# - **Security**: Malicious use potential, data poisoning, prompt injection vulnerabilities
# - **Environmental**: High energy consumption
#
# ## Regulatory Environment
# EU AI Act, US Executive Orders, and China's regulations focus on transparency, data privacy, content authentication, and IP rights.
#
# ## Market Impact
# Market valued at $10-40B (2023), projected 30-40% CAGR through 2030, with rapid cross-sector adoption and significant tech investment.
#
# ## Future Outlook
# Multimodal integration, improved efficiency and reasoning, enhanced personalization, with applications expanding into scientific discovery, healthcare, climate modeling, and education transformation.
#
# ## Best Practices
# Verify outputs, understand limitations, ensure ethical use, maintain transparency about AI-generated content, implement human oversight, and protect data privacy.

# %% [markdown]
# ## Part 1 Complete
#
# You've learned how to use agents as tools in Strands Agents. But look at the **observability cost**: every tool function needed ~50 lines of manual `emit_span()` boilerplate just to get basic tracing.

# %% [markdown]
# ---
# # Part 2: Strands Built-in Telemetry — What You Get for Free
#
# The manual `emit_span()` approach from Part 1 is painful. But does it have to be?
#
# Strands Agents SDK includes **automatic OpenTelemetry instrumentation**. You don't need manual span emission for basic tracing. Let's see what it gives us — and critically, **where it stops**.
#
# Reference: [Strands Observability Docs](https://strandsagents.com/docs/user-guide/observability-evaluation/traces/#opentelemetry-integration)

# %%
# ============================================================
# Strands Built-in Telemetry Setup
# ============================================================
# Reference: https://strandsagents.com/docs/user-guide/observability-evaluation/traces/
#
# No manual emit_span() needed. Just environment variables + one setup call.

import os

# Point to any OTLP-compatible backend: Jaeger, Grafana Tempo, Datadog, Langfuse, Arize, etc.
os.environ["OTEL_EXPORTER_OTLP_ENDPOINT"] = "http://localhost:4317"

# For AWS X-Ray, use ADOT (AWS Distro for OpenTelemetry) Collector as intermediate layer
# for sampling, filtering, batching, and routing.
# Reference: https://aws.amazon.com/otel/partners/

# One-time setup call at application startup
from strands.telemetry import StrandsTelemetry

telemetry = StrandsTelemetry()
telemetry.setup_otlp_exporter()

print("✓ Strands built-in telemetry enabled")
print("  Every Agent.__call__ now automatically emits OTel spans.")
print()
print("What's captured automatically:")
print("  ✓ Agent name")
print("  ✓ Model ID")  
print("  ✓ Tool calls (name, input, output)")
print("  ✓ Token counts (input/output)")
print("  ✓ Latency per step")
print("  ✓ Agent cycle/loop iterations")
print("  ✓ Errors and exceptions")
print()
print("What's NOT captured:")
print("  ✗ Session-level execution graph")
print("  ✗ Parent-child delegation relationships across agents")
print("  ✗ Anomaly detection (retry storms, token explosion)")
print("  ✗ Session cost attribution")
print("  ✗ Execution lineage / root-cause analysis")
print("  ✗ Context evolution / instruction drift")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 21
#      18 from strands.telemetry import StrandsTelemetry
#      20 telemetry = StrandsTelemetry()
# ---> 21 telemetry.setup_otlp_exporter()
#      23 print("✓ Strands built-in telemetry enabled")
#      24 print("  Every Agent.__call__ now automatically emits OTel spans.")
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/site-packages/strands/telemetry/config.py:162, in StrandsTelemetry.setup_otlp_exporter(self, **kwargs)
#     148 def setup_otlp_exporter(self, **kwargs: Any) -> "StrandsTelemetry":
#     149     """Set up OTLP exporter for the tracer provider.
#     150
#     151     Args:
#    (...)
#     160     keyword arguments provided will be forwarded to the OTLPSpanExporter.
#     161     """
# --> 162     from opentelemetry.exporter.otlp.proto.http.trace_exporter import OTLPSpanExporter
#     164     try:
#     165         otlp_exporter = OTLPSpanExporter(**kwargs)
#
# ModuleNotFoundError: No module named 'opentelemetry.exporter'

# %%
# Same agents as Part 1 — but now with ZERO manual emit_span() code.
# Strands telemetry captures spans automatically.

@tool
def research_assistant_native(query: str) -> str:
    """Research specialist - provides factual, well-sourced information."""
    agent = Agent(
        model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
        system_prompt=RESEARCH_ASSISTANT_PROMPT,
    )
    response = agent(query)
    return str(response)


@tool
def product_recommendation_native(query: str) -> str:
    """Product recommendation specialist - personalized suggestions."""
    agent = Agent(
        model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
        system_prompt="You are a specialized product recommendation assistant. Provide personalized product suggestions.",
    )
    response = agent(query)
    return str(response)


@tool
def trip_planning_native(query: str) -> str:
    """Travel planning specialist - detailed itineraries."""
    agent = Agent(
        model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
        system_prompt="You are a specialized travel planning assistant. Create detailed travel itineraries.",
    )
    response = agent(query)
    return str(response)


print("Tools defined — zero observability code inside them.")
print("Compare to Part 1 where each tool had ~50 lines of emit_span() boilerplate.")

# %%
# Run the orchestrator with Strands native telemetry active
orchestrator_native = Agent(
    model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    system_prompt=MAIN_SYSTEM_PROMPT,
    tools=[research_assistant_native, product_recommendation_native, trip_planning_native],
)

os.environ["BYPASS_TOOL_CONSENT"] = "true"
response = orchestrator_native("Research Spain and plan a 3-day trip")

print("\n✓ Spans emitted automatically to OTLP endpoint")
print("  No manual emit_span() code needed!")
print("  Strands captured: agent names, model IDs, tool calls, tokens, latency, errors")

# %% [markdown]
# ## What Strands Built-in Telemetry Does NOT Give You
#
# Strands telemetry solves the "observability tax" from Part 1. But it produces **flat spans** — individual events with timestamps. There is no session awareness.
#
# Questions you still **CANNOT** answer with built-in telemetry:
#
# | Question | Strands Built-in | What's Needed |
# |----------|:---------------:|---------------|
# | Which agent called which? (delegation graph) | ❌ | Session reconstruction |
# | Why did the orchestrator route to the wrong specialist? | ❌ | Execution lineage |
# | Is this agent stuck in a retry loop? (each call "succeeds") | ❌ | Anomaly detection |
# | How much did this entire SESSION cost? | ❌ Per-span only | Session cost attribution |
# | What context was lost during compaction? | ❌ | Context evolution tracking |
# | Can I replay step-by-step what happened? | ❌ | Session timeline replay |
# | Did this session violate any governance policies? | ❌ | Governance evaluation |
#
# **The gap:** Strands gives you **span-level telemetry** — *what happened, when*.
#
# What's missing is **session-level intelligence** — *why it happened, what went wrong, how to fix it*.
#
# This is the difference between a log file and a debugger.

# %% [markdown]
# ---
# # Part 3: Session Intelligence — The Layer Above Spans
#
# Strands telemetry gives you spans. But spans alone don't answer session-level questions.
#
# LexiLensAI sits **above** your tracing layer (whether Strands built-in, Langfuse, Datadog, or your own OTel collector) and reconstructs spans into **sessions** — the complete execution history of a multi-agent workflow.
#
# Think of it as:
# - **Strands Telemetry** = individual security cameras (each shows one room)
# - **LexiLensAI** = the security control room (reconstructs the full story across all cameras)
#
# The LexiLens SDK below works alongside Strands telemetry or independently. It adds:
# - Session reconstruction with delegation graphs
# - Automatic parent-child relationship tracking via call stack
# - Real-time anomaly detection (retry storms, token explosion)
# - Session-level cost attribution
# - Timeline replay capability

# %% [markdown]
# ## The Observability Tax — Quantified

# %%
# Let's count what Part 1 cost us in boilerplate

manual_lines_per_tool = 20  # emit_span wrappers, try/except, span_id generation
num_tools = 3
orchestrator_overhead = 10  # start/end spans around each orchestrator call

total_manual_lines = (manual_lines_per_tool * num_tools) + orchestrator_overhead
agent_logic_lines = 5 * num_tools  # actual agent creation + invocation per tool

print("=" * 60)
print("OBSERVABILITY APPROACH COMPARISON")
print("=" * 60)
print()
print("Part 1 - Manual emit_span():")
print(f"  Observability code:   {total_manual_lines} lines")
print(f"  Agent logic:          {agent_logic_lines} lines")
print(f"  Ratio:                {total_manual_lines/agent_logic_lines:.1f}x more observability than logic!")
print(f"  Session awareness:    ❌ None")
print(f"  Anomaly detection:    ❌ None")
print()
print("Part 2 - Strands Built-in Telemetry:")
print(f"  Observability code:   3 lines (env var + setup call)")
print(f"  Agent logic:          {agent_logic_lines} lines")
print(f"  Ratio:                Minimal overhead ✓")
print(f"  Session awareness:    ❌ None (flat spans)")
print(f"  Anomaly detection:    ❌ None")
print()
print("Part 3 - LexiLensAI (below):")
print(f"  Observability code:   1 line (LexiLens.init())")
print(f"  Agent logic:          {agent_logic_lines} lines")
print(f"  Ratio:                Minimal overhead ✓")
print(f"  Session awareness:    ✓ Full execution graph")
print(f"  Anomaly detection:    ✓ Retry storms, token explosion, context drift")
print("=" * 60)

# %% [markdown]
# ## LexiLensAI SDK — Session-Native Auto-Instrumentation
#
# The SDK monkey-patches the Strands Agent class to automatically emit **session-aware** spans for every agent invocation, tool call, and delegation.
#
# Key differences from Strands built-in telemetry:
# - **Parent-child tracking** via call stack inspection (not just flat spans)
# - **Session-level anomaly detection** running in real-time
# - **Delegation graph reconstruction** from span relationships
# - **Session cost attribution** (total cost per session, per agent)
#
# Zero changes to your agent code.

# %%
# lexilens/sdk.py - Session-native auto-instrumentation for AI agents
# This is a working implementation of the LexiLensAI SDK

import json
import uuid
import time
import functools
from datetime import datetime, timezone
from pathlib import Path
from dataclasses import dataclass, field, asdict
from typing import Optional, Dict, List, Any
from collections import defaultdict


@dataclass
class Span:
    trace_id: str
    span_id: str
    parent_span_id: Optional[str]
    session_id: str
    agent_name: str
    event: str
    status: str = "success"
    start_time: Optional[str] = None
    end_time: Optional[str] = None
    duration_ms: Optional[float] = None
    token_input: Optional[int] = None
    token_output: Optional[int] = None
    metadata: Dict = field(default_factory=dict)


class SessionTracker:
    """Tracks execution at the SESSION level, not just span level.
    
    This is what differentiates LexiLensAI from span-level tools:
    - Strands/Langfuse/Datadog see individual spans
    - SessionTracker sees the complete execution session as a graph
    """
    
    def __init__(self, session_id: str):
        self.session_id = session_id
        self.spans: List[Span] = []
        self.delegation_chain: List[str] = []
        self.total_tokens_in = 0
        self.total_tokens_out = 0
        self.tool_call_counts: Dict[str, int] = defaultdict(int)
        self.retry_tracker: Dict[str, List[float]] = defaultdict(list)
        self.anomalies: List[Dict] = []
    
    def add_span(self, span: Span):
        self.spans.append(span)
        if span.token_input:
            self.total_tokens_in += span.token_input
        if span.token_output:
            self.total_tokens_out += span.token_output
        
        # Track tool calls for retry detection
        tool_key = f"{span.agent_name}:{span.metadata.get('input', '')[:50]}"
        self.tool_call_counts[span.agent_name] += 1
        self.retry_tracker[tool_key].append(time.time())
        
        # Real-time anomaly detection
        self._check_retry_storm(tool_key)
        self._check_token_explosion(span)
    
    def _check_retry_storm(self, tool_key: str):
        """Detect: same agent called 3+ times in <60s with similar input.
        Each individual call 'succeeds' — only visible at session level."""
        calls = self.retry_tracker[tool_key]
        if len(calls) >= 3:
            recent = [t for t in calls if time.time() - t < 60]
            if len(recent) >= 3:
                self.anomalies.append({
                    "type": "retry_storm",
                    "severity": "high",
                    "agent": tool_key.split(":")[0],
                    "detail": f"Agent called {len(recent)}x in <60s with similar input",
                    "timestamp": datetime.now(timezone.utc).isoformat()
                })
    
    def _check_token_explosion(self, span: Span):
        """Detect: single agent response consuming disproportionate tokens."""
        if span.token_output and span.token_output > 4000:
            self.anomalies.append({
                "type": "token_explosion",
                "severity": "medium",
                "agent": span.agent_name,
                "detail": f"Single response used {span.token_output} output tokens",
                "timestamp": datetime.now(timezone.utc).isoformat()
            })
    
    def get_delegation_graph(self) -> Dict[str, List[str]]:
        """Returns adjacency list of agent delegations.
        This is impossible to reconstruct from flat spans alone."""
        graph = defaultdict(set)
        span_map = {s.span_id: s for s in self.spans}
        for span in self.spans:
            if span.parent_span_id and span.parent_span_id in span_map:
                parent = span_map[span.parent_span_id]
                if parent.agent_name != span.agent_name:
                    graph[parent.agent_name].add(span.agent_name)
        return {k: list(v) for k, v in graph.items()}
    
    def summary(self) -> Dict:
        return {
            "session_id": self.session_id,
            "total_spans": len(self.spans),
            "total_tokens": {"input": self.total_tokens_in, "output": self.total_tokens_out},
            "unique_agents": list(set(s.agent_name for s in self.spans)),
            "delegation_graph": self.get_delegation_graph(),
            "anomalies": self.anomalies,
            "duration_ms": self._session_duration()
        }
    
    def _session_duration(self) -> Optional[float]:
        if len(self.spans) < 2:
            return None
        first = self.spans[0].start_time
        last = self.spans[-1].end_time or self.spans[-1].start_time
        if first and last:
            t1 = datetime.fromisoformat(first)
            t2 = datetime.fromisoformat(last)
            return (t2 - t1).total_seconds() * 1000
        return None


def _extract_agent_name(agent_self) -> str:
    """Extract a meaningful name from a Strands Agent instance."""
    name = getattr(agent_self, 'name', None)
    if name and name not in ("Agent", "Strands Agents"):
        return name
    
    prompt = getattr(agent_self, 'system_prompt', None)
    if prompt:
        lower = prompt.strip().lower()
        if "research" in lower:
            return "research_agent"
        elif "product" in lower or "recommendation" in lower:
            return "product_recommendation_agent"
        elif "travel" in lower or "trip" in lower or "itinerar" in lower:
            return "trip_planning_agent"
        elif "summar" in lower:
            return "summary_agent"
        elif "route" in lower or "orchestrat" in lower or "specialized agents" in lower:
            return "orchestrator"
        else:
            snippet = prompt.strip()[:40].replace("\n", " ").strip()
            return snippet.replace(" ", "_")[:30]
    
    return "unnamed_agent"


def _extract_tokens_from_response(response) -> tuple:
    """Extract token counts from Strands Agent response object."""
    token_in = None
    token_out = None
    
    try:
        msg = getattr(response, 'message', None)
        if msg and isinstance(msg, dict):
            metadata = msg.get('metadata', {})
            usage = metadata.get('usage', {})
            token_in = usage.get('inputTokens') or usage.get('input_tokens')
            token_out = usage.get('outputTokens') or usage.get('output_tokens')
            if token_in:
                return (token_in, token_out)
    except (AttributeError, TypeError, KeyError):
        pass
    
    try:
        metrics = getattr(response, 'metrics', None)
        if metrics:
            token_in = getattr(metrics, 'inputTokens', None) or getattr(metrics, 'input_tokens', None)
            token_out = getattr(metrics, 'outputTokens', None) or getattr(metrics, 'output_tokens', None)
            if token_in:
                return (token_in, token_out)
    except (AttributeError, TypeError):
        pass
    
    try:
        usage = getattr(response, 'usage', None)
        if usage and isinstance(usage, dict):
            token_in = usage.get('inputTokens') or usage.get('input_tokens')
            token_out = usage.get('outputTokens') or usage.get('output_tokens')
            if token_in:
                return (token_in, token_out)
    except (AttributeError, TypeError):
        pass
    
    return (token_in, token_out)


class LexiLens:
    """
    LexiLensAI Auto-Instrumentation SDK.
    
    Sits ABOVE span-level telemetry (Strands built-in, Langfuse, Datadog)
    to provide SESSION-level intelligence:
    - Delegation graph reconstruction
    - Real-time anomaly detection
    - Session cost attribution
    - Execution lineage tracking
    
    Usage:
        lexilens = LexiLens.init(service_name="my-agent-app")
        # That's it. All Strands Agent calls are now session-traced.
    """
    
    _instance = None
    
    def __init__(self, service_name: str, output_dir: Optional[str] = None):
        self.service_name = service_name
        self.trace_id = str(uuid.uuid4())
        self.session_id = str(uuid.uuid4())
        self.output_dir = Path(output_dir) if output_dir else Path("./lexilens_traces")
        self.output_dir.mkdir(parents=True, exist_ok=True)
        self.trace_file = self.output_dir / f"session_{self.session_id[:8]}.jsonl"
        self.session = SessionTracker(self.session_id)
        self._span_stack: List[str] = []
        self._original_agent_call = None
        self._patched = False
    
    @classmethod
    def init(cls, service_name: str = "strands-app", output_dir: Optional[str] = None) -> 'LexiLens':
        """Initialize LexiLensAI. Patches Strands Agent automatically."""
        instance = cls(service_name=service_name, output_dir=output_dir)
        instance._patch_strands()
        cls._instance = instance
        print(f"[LexiLens] Initialized for '{service_name}'")
        print(f"[LexiLens] Session: {instance.session_id[:8]}...")
        print(f"[LexiLens] Traces -> {instance.trace_file}")
        return instance
    
    def _patch_strands(self):
        """Monkey-patch strands.Agent.__call__ to auto-emit session-aware spans."""
        if self._patched:
            return
        
        from strands import Agent as StrandsAgent
        original_call = StrandsAgent.__call__
        lexilens_ref = self
        
        @functools.wraps(original_call)
        def instrumented_call(agent_self, *args, **kwargs):
            agent_name = _extract_agent_name(agent_self)
            
            # KEY DIFFERENCE: parent tracking via call stack
            # Strands built-in telemetry doesn't do this
            parent_span_id = lexilens_ref._span_stack[-1] if lexilens_ref._span_stack else None
            span_id = str(uuid.uuid4())
            
            lexilens_ref._span_stack.append(span_id)
            
            start = datetime.now(timezone.utc)
            span = Span(
                trace_id=lexilens_ref.trace_id,
                span_id=span_id,
                parent_span_id=parent_span_id,
                session_id=lexilens_ref.session_id,
                agent_name=agent_name,
                event="agent_invocation",
                start_time=start.isoformat(),
                metadata={"input": str(args[0])[:200] if args else ""}
            )
            
            try:
                response = original_call(agent_self, *args, **kwargs)
                
                end = datetime.now(timezone.utc)
                span.end_time = end.isoformat()
                span.duration_ms = (end - start).total_seconds() * 1000
                span.status = "success"
                
                token_in, token_out = _extract_tokens_from_response(response)
                span.token_input = token_in
                span.token_output = token_out
                span.metadata["output_size"] = len(str(response))
                
                return response
                
            except Exception as e:
                end = datetime.now(timezone.utc)
                span.end_time = end.isoformat()
                span.duration_ms = (end - start).total_seconds() * 1000
                span.status = "error"
                span.metadata["error"] = str(e)
                raise
                
            finally:
                # Record span with session context + run anomaly detection
                lexilens_ref.session.add_span(span)
                lexilens_ref._write_span(span)
                lexilens_ref._span_stack.pop()
        
        StrandsAgent.__call__ = instrumented_call
        self._original_agent_call = original_call
        self._patched = True
    
    def _write_span(self, span: Span):
        with open(self.trace_file, "a") as f:
            f.write(json.dumps(asdict(span)) + "\n")
    
    def report(self):
        """Print session summary with anomaly detection results."""
        s = self.session.summary()
        print("\n" + "=" * 60)
        print("LEXILENS SESSION REPORT")
        print("=" * 60)
        print(f"Session:        {s['session_id'][:8]}...")
        print(f"Total spans:    {s['total_spans']}")
        print(f"Tokens:         {s['total_tokens']['input'] or 0} in / {s['total_tokens']['output'] or 0} out")
        print(f"Agents used:    {', '.join(s['unique_agents'])}")
        if s['duration_ms']:
            print(f"Duration:       {s['duration_ms']:.0f}ms")
        else:
            print("Duration:       N/A")
        
        if s['delegation_graph']:
            print(f"\nDelegation Graph:")
            for parent, children in s['delegation_graph'].items():
                for child in children:
                    print(f"  {parent} -> {child}")
        
        if s['anomalies']:
            print(f"\n⚠️  ANOMALIES DETECTED: {len(s['anomalies'])}")
            for a in s['anomalies']:
                print(f"  [{a['severity'].upper()}] {a['type']}: {a['detail']}")
        else:
            print(f"\n✓ No anomalies detected")
        
        print("=" * 60)
        return s
    
    def unpatch(self):
        """Restore original Strands Agent behavior."""
        if self._original_agent_call and self._patched:
            from strands import Agent as StrandsAgent
            StrandsAgent.__call__ = self._original_agent_call
            self._patched = False
            print("[LexiLens] Unpatched - original Agent behavior restored")


print("LexiLens SDK loaded — session intelligence layer ready")

# %% [markdown]
# ## Same Agents, Session-Level Intelligence
#
# Now let's run the **exact same orchestrator pattern** — with LexiLensAI providing session intelligence above the span layer.
#
# Notice: **no changes to agent code.** One `init()` call does everything.

# %%
# Initialize LexiLensAI - this is the ONLY line you need
lexilens = LexiLens.init(
    service_name="strands-multi-agent-demo",
    output_dir="./lexilens_traces"
)

# %%
# LOOK: No emit_span() anywhere. Same agent logic as Part 2.
# But now we get SESSION intelligence, not just flat spans.

@tool
def research_assistant_v3(query: str) -> str:
    """Research specialist - provides factual, well-sourced information."""
    agent = Agent(
        model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
        system_prompt=RESEARCH_ASSISTANT_PROMPT,
    )
    response = agent(query)
    return str(response)


@tool  
def product_recommendation_v3(query: str) -> str:
    """Product recommendation specialist - personalized suggestions."""
    agent = Agent(
        model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
        system_prompt="You are a specialized product recommendation assistant. Provide personalized product suggestions.",
    )
    response = agent(query)
    return str(response)


@tool
def trip_planning_v3(query: str) -> str:
    """Travel planning specialist - detailed itineraries."""
    agent = Agent(
        model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
        system_prompt="You are a specialized travel planning assistant. Create detailed travel itineraries.",
    )
    response = agent(query)
    return str(response)


print("Tools defined — same as Part 2 (zero observability code inside)")
print("But LexiLens is tracking: parent-child relationships, session graph, anomalies")

# %%
# Create orchestrator with clean tools
orchestrator_v3 = Agent(
    model="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    system_prompt=MAIN_SYSTEM_PROMPT,
    tools=[research_assistant_v3, product_recommendation_v3, trip_planning_v3],
)

os.environ["BYPASS_TOOL_CONSENT"] = "true"

# Run a multi-agent query - LexiLens captures SESSION intelligence automatically
response = orchestrator_v3("Research Spain and plan me a 7-day trip with hotel recommendations")

# %%
# One call to see the full SESSION picture — not just spans
session_data = lexilens.report()

# %% [markdown]
# ## Session Graph Visualization
#
# LexiLensAI reconstructs the execution as a **directed session graph** — showing exactly which agent delegated to which, the token cost at each node, and where anomalies occurred.
#
# This is impossible to produce from flat spans alone. You need parent-child relationships tracked across the call stack.

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
print(f"matplotlib {matplotlib.__version__} loaded")

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from collections import defaultdict

def visualize_session_graph(session, title="Agent Session Graph"):
    """
    Renders the session delegation graph using matplotlib.
    Nodes = agents, Edges = delegations, Node size = token usage.
    """
    spans = session.spans
    if not spans:
        print("No spans recorded yet.")
        return
    
    # Build graph data
    nodes = {}
    edges = []
    span_map = {s.span_id: s for s in spans}
    
    for span in spans:
        name = span.agent_name
        if name not in nodes:
            nodes[name] = {"tokens_in": 0, "tokens_out": 0, "calls": 0, "has_anomaly": False}
        nodes[name]["tokens_in"] += span.token_input or 0
        nodes[name]["tokens_out"] += span.token_output or 0
        nodes[name]["calls"] += 1
        
        if span.parent_span_id and span.parent_span_id in span_map:
            parent_name = span_map[span.parent_span_id].agent_name
            edges.append((parent_name, name))
    
    # Check anomalies
    for anomaly in session.anomalies:
        agent = anomaly.get("agent", "")
        if agent in nodes:
            nodes[agent]["has_anomaly"] = True
    
    # Layout: simple hierarchical
    levels = defaultdict(list)
    all_targets = set(e[1] for e in edges)
    all_sources = set(e[0] for e in edges)
    roots = all_sources - all_targets
    if not roots:
        roots = {spans[0].agent_name}
    
    # BFS for levels
    visited = set()
    queue = [(r, 0) for r in roots]
    while queue:
        node, level = queue.pop(0)
        if node in visited:
            continue
        visited.add(node)
        levels[level].append(node)
        for src, tgt in edges:
            if src == node and tgt not in visited:
                queue.append((tgt, level + 1))
    
    for name in nodes:
        if name not in visited:
            max_level = max(levels.keys()) + 1 if levels else 0
            levels[max_level].append(name)
    
    # Calculate positions
    positions = {}
    for level, names in levels.items():
        for i, name in enumerate(names):
            x = (i + 0.5) * (10.0 / max(len(names), 1))
            y = -level * 2.5
            positions[name] = (x, y)
    
    # Draw
    fig, ax = plt.subplots(1, 1, figsize=(12, 8))
    ax.set_xlim(-1, 11)
    y_vals = [p[1] for p in positions.values()]
    ax.set_ylim(min(y_vals) - 2, max(y_vals) + 2)
    ax.axis('off')
    ax.set_title(title, fontsize=16, fontweight='bold', pad=20)
    
    # Draw edges
    drawn_edges = set()
    for src, tgt in edges:
        edge_key = (src, tgt)
        if edge_key in drawn_edges:
            continue
        drawn_edges.add(edge_key)
        if src in positions and tgt in positions:
            x1, y1 = positions[src]
            x2, y2 = positions[tgt]
            ax.annotate("", xy=(x2, y2), xytext=(x1, y1),
                arrowprops=dict(arrowstyle="->", color="#555555", lw=2))
    
    # Draw nodes
    for name, pos in positions.items():
        info = nodes.get(name, {"tokens_in": 0, "tokens_out": 0, "calls": 0, "has_anomaly": False})
        
        if info["has_anomaly"]:
            color, edge_color = "#FF4444", "#CC0000"
        elif name in roots:
            color, edge_color = "#4A90D9", "#2A5F8F"
        else:
            color, edge_color = "#5CB85C", "#3D8B3D"
        
        circle = plt.Circle(pos, 0.6, color=color, ec=edge_color, lw=2, zorder=5)
        ax.add_patch(circle)
        
        short_name = name[:20] if len(name) > 20 else name
        ax.text(pos[0], pos[1] + 0.05, short_name, ha='center', va='center',
                fontsize=8, fontweight='bold', color='white', zorder=6)
        
        token_str = f"{info['tokens_in']+info['tokens_out']} tok | {info['calls']}x"
        ax.text(pos[0], pos[1] - 0.9, token_str, ha='center', va='top',
                fontsize=7, color='#666666')
    
    # Legend
    legend_elements = [
        mpatches.Patch(color='#4A90D9', label='Orchestrator'),
        mpatches.Patch(color='#5CB85C', label='Specialist Agent'),
        mpatches.Patch(color='#FF4444', label='Anomaly Detected'),
    ]
    ax.legend(handles=legend_elements, loc='lower right', fontsize=9)
    
    plt.tight_layout()
    plt.savefig("session_graph.png", dpi=150, bbox_inches='tight')
    plt.show()
    print(f"\nGraph saved to session_graph.png")


# Render the session graph from our auto-instrumented run
visualize_session_graph(lexilens.session, title="Multi-Agent Session Graph — LexiLensAI Session Intelligence")

# %% [markdown]
# ## Anomaly Detection: Catching Silent Failures
#
# Traditional tracing (including Strands built-in) shows "success" for every span. But LexiLensAI detects **session-level anomalies** — problems that only become visible when you look at the execution as a whole.
#
# Let's simulate a retry storm: an agent calling itself repeatedly with the same query. Each call "succeeds." Strands telemetry sees 5 successful spans. LexiLensAI sees a pattern.

# %%
# Simulate a retry storm - agent called 5x with same input in rapid succession
# In production, this happens when an agent isn't satisfied with its own output
# and re-queries. Each individual call "succeeds" but the session is burning tokens.

import time

print("Simulating retry storm...\n")
print("Each call returns 'success'. Strands telemetry sees nothing wrong.")
print("LexiLensAI analyzes the SESSION pattern:\n")

for i in range(5):
    fake_span = Span(
        trace_id=lexilens.trace_id,
        span_id=str(uuid.uuid4()),
        parent_span_id=lexilens._span_stack[-1] if lexilens._span_stack else None,
        session_id=lexilens.session_id,
        agent_name="research_agent_retry_sim",
        event="agent_invocation",
        status="success",  # Each call "succeeds"!
        start_time=datetime.now(timezone.utc).isoformat(),
        end_time=datetime.now(timezone.utc).isoformat(),
        duration_ms=1200 + (i * 300),
        token_input=500,
        token_output=2000,
        metadata={"input": "What are the best hotels in Barcelona?"}  # Same query each time
    )
    lexilens.session.add_span(fake_span)
    time.sleep(0.1)  # Rapid succession

# Now check what LexiLens caught
print("=" * 50)
print("STRANDS BUILT-IN TELEMETRY SEES:")
print("  span_1: status=success, latency=1200ms")
print("  span_2: status=success, latency=1500ms")
print("  span_3: status=success, latency=1800ms")
print("  span_4: status=success, latency=2100ms")
print("  span_5: status=success, latency=2400ms")
print("  → Conclusion: everything is fine ✓")
print("=" * 50)
print()
print("LEXILENSAI SESSION INTELLIGENCE SEES:")

lexilens.report()

# %% [markdown]
# ## Key Insight: Three Levels of Observability
#
# | Aspect | Manual emit_span() | Strands Built-in | LexiLensAI |
# |--------|:------------------:|:----------------:|:----------:|
# | Code overhead | 50+ lines per tool | 1 setup call | 1 setup call |
# | What you get | Custom spans | Flat OTel spans | Session graphs |
# | Delegation tracking | Manual parent_span_id | ❌ | ✓ Automatic |
# | Session awareness | ❌ | ❌ | ✓ Full graph |
# | Anomaly detection | ❌ | ❌ | ✓ Real-time |
# | Cost attribution | Per-span (manual) | Per-span (auto) | Per-session + per-agent |
# | Timeline replay | ❌ | ❌ | ✓ Session reconstruction |
# | Works with | Custom code | Strands only | Any OTel source |
# | Governance | ❌ | ❌ | ✓ Policy evaluation |
#
# **The progression:**
# 1. **Manual** → You see what you remembered to instrument
# 2. **Strands telemetry** → You see every span automatically
# 3. **LexiLensAI** → You understand what the session DID and WHY
#
# **Spans answer:** *What happened?*
# **Sessions answer:** *Why did it happen? What went wrong? How do I fix it?*
#
# ---
#
# ## Architecture: How The Pieces Fit
#
# ```
# ┌─────────────────────────────────────────────────────────────┐
# │  Your Multi-Agent Application (Strands, LangChain, etc.)    │
# └──────────────────────┬──────────────────────────────────────┘
#                        │
#             ┌──────────┴──────────┐
#             │                     │
#             ▼                     ▼
# ┌───────────────────┐   ┌────────────────────────┐
# │ Strands Telemetry │   │ LexiLens SDK           │
# │ (Span-level)      │   │ (Session-level)        │
# │ • Agent names     │   │ • Delegation graphs    │
# │ • Tool calls      │   │ • Parent-child links   │
# │ • Token counts    │   │ • Anomaly detection    │
# │ • Latency         │   │ • Session cost         │
# │ • Errors          │   │ • Execution lineage    │
# └────────┬──────────┘   └──────────┬─────────────┘
#          │                         │
#          ▼                         ▼
# ┌───────────────────┐   ┌────────────────────────┐
# │ OTel Collector    │   │ Session Store          │
# │ (X-Ray/Jaeger/    │   │ (JSONL → PostgreSQL →  │
# │  Tempo/Datadog)   │   │  agent-session-graph)  │
# └───────────────────┘   └──────────┬─────────────┘
#                                    │
#                                    ▼
#                         ┌────────────────────────┐
#                         │ LexiLensAI Platform    │
#                         │ • Session replay       │
#                         │ • Governance engine    │
#                         │ • Root cause analysis  │
#                         │ • Cost attribution     │
#                         │ • Multi-session trends │
#                         └────────────────────────┘
# ```
#
# **Strands telemetry and LexiLensAI are complementary, not competing.**
#
# Strands gives you the raw spans. LexiLensAI reconstructs them into sessions and tells you what went wrong.
#
# ---
#
# *Built by CurvSort | [github.com/curvsort/agent-session-graph](https://github.com/curvsort/agent-session-graph) | [curvsort.com/lexilensai](https://www.curvsort.com/lexilensai)*
